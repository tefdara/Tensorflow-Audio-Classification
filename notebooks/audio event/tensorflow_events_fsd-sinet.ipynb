# %%
import os, sys
sys.path.append("../../")
from common.base import MetaData, Processor
from common.predictors import TensorflowFSDSINet

# %% [markdown]
# ## Download Pretrained Models

# %% [markdown]
# In this step, we download and save four machine learning models and their associated metadata files. These models are used for audio feature extraction and classification. We define the URLs for the models and metadata files at the beginning of the code, and we use the `os.path.join()` function to define the file paths where the downloaded files will be saved.
#
# Before downloading the files, we check if they already exist in the specified file paths using the `os.path.exists()` function. If any of the files don't exist, we use the `wget` command to download the files from the URLs and save them to the specified file paths. We use the `-q` option to suppress output from the `wget` command, so the code doesn't print any messages to the console.

# %%
# embedding model
embedding_model_url = ''
embedding_model_json_url = ''
embedding_model_file = os.path.join('../..', 'models', os.path.basename(embedding_model_url))
embedding_model_json = os.path.join('../..', 'models', os.path.basename(embedding_model_json_url))

# classification model
model_url = 'https://essentia.upf.edu/models/audio-event-recognition/fsd-sinet/fsd-sinet-vgg42-tlpf_aps-1.pb'
model_json_url = 'https://essentia.upf.edu/models/audio-event-recognition/fsd-sinet/fsd-sinet-vgg42-tlpf_aps-1.json'
model_file = os.path.join('../..', 'models', os.path.basename(model_url))
model_json = os.path.join('../..', 'models', os.path.basename(model_json_url))

# %%
has_embedding_model = True if(embedding_model_json_url != '' and embedding_model_url != '') else False
if(not os.path.exists(model_json)):
    # !wget -q $model_json_url -P ../../models
if(not os.path.exists(model_file)):
    # !wget -q $model_url -P ../../models
if(has_embedding_model):
    if(not os.path.exists(embedding_model_file)):
        # !wget -q $embedding_model_url -P ../../models
    if(not os.path.exists(embedding_model_json)):
        # !wget -q $embedding_model_json_url -P ../../models

# %% [markdown]
# ## Load Audio
#
# Audio file can be a single file or a directory of sounds

# %%
# open a file dialog to select an audio file or set open_file_dialog to False and set file_path to the audio file
from common.base import file_dialog as fd 
open_file_dialog = False
file_path = '/Users/dtef/Repos/Sync/Audio/Sounds/Sound Libraries/Tef/OK 01/Burning Tornadic Debris Stereo_01/short'
if(open_file_dialog):
    audio_file = fd()
else: audio_file = file_path
    
processor = Processor(audio_file_path=audio_file)
# gets a list of audio files in the selected directory
audio_files = processor.audio_files

# %% [markdown]
# ## Metadata
#
# Next we have to initialise a `MetaData` object with the `model_json` argument, which is assumed to be a file path to a JSON file containing metadata for the TensorFlow model. The `MetaData` object is used to extract the schema and layer information for the model. We do this here since we don't want to initialise a unique instance of the metadata for each audio file we are processing.
#
# The `get_schema()` method of the `MetaData` object is used to extract the schema for the model. The schema is a dictionary that contains information about the model's input and output layers, including their names, shapes, and data types. The schema is printed to the console using the `print()` function.
#
# The `get_layer()` method of the `MetaData` object is used to extract the input and output layers for the model. The `model_input_layer` and `model_output_layer` variables are assigned the input and output layers, respectively. These variables can be used later in the code to feed data into the model and extract the model's output.

# %% [markdown]
# ####    Embeddings metadata

# %%
if(has_embedding_model):
    embeddings_metadata = MetaData(embedding_model_json)
    embeddings_schema = embeddings_metadata.get_schema()

    embeddings_input_layer = embeddings_metadata.get_layer('input')
    print("Detected input layer: ", embeddings_input_layer)
    embeddings_output_layer = embeddings_metadata.get_layer('output', 'embeddings')
    print("Detected output layer: ", embeddings_output_layer)

    print(embeddings_schema)

# %% [markdown]
# ####  Predictor's metadata

# %%
classifier_metadata = MetaData(model_json)
classifier_schema = classifier_metadata.get_schema()

classifier_input_layer = classifier_metadata.get_layer('input')
print("Detected input layer: ", classifier_input_layer)
classifier_output_layer = classifier_metadata.get_layer('output', 'predictions')
print("Detected output layer: ", classifier_output_layer)

print(classifier_schema)
# Out:
# Detected input layer:  x
# Detected output layer:  model/predictions/Sigmoid
# {'inputs': [{'name': 'x', 'type': 'float', 'shape': ['batch_size', 96, 101, 1]}], 'outputs': [{'name': 'model/predictions/Sigmoid', 'type': 'float', 'shape': ['batch_size', 200], 'op': 'fully connected', 'output_purpose': 'predictions'}, {'name': 'model/global_max_pooling1d/Max', 'type': 'float', 'shape': ['batch_size', 512], 'op': 'max pooling', 'output_purpose': 'embeddings'}]}

# %% [markdown]
# # Classify

# %% [markdown]
# Since our model is trained on the VGGish embeddings, we need to use the same schema. We could use the `TensorflowPredictVGGish` algorithm because it generates the required mel-spectrogram. This approach won't need any embeddings. But for better learning transfer and noise reduction, the embeddings can be inputed to `TensorflowPredict2D`.
#
# The extractor and classifier used bellow exist in the classifiers.py file. This to reduce the size of the notebook

# %%
classifier = TensorflowFSDSINet(model_file, classifier_input_layer, classifier_output_layer)
stats = processor.classify_audio(classifier, classifier_metadata)
# Out:
# Burning_short_9.wav  Label:  Accelerating and revving and vroom  Probability:  0.0%
# Burning_short_9.wav  Label:  Accordion  Probability:  0.0%
# Burning_short_9.wav  Label:  Acoustic guitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Aircraft  Probability:  0.2%
# Burning_short_9.wav  Label:  Alarm  Probability:  0.2%
# Burning_short_9.wav  Label:  Animal  Probability:  16.3%
# Burning_short_9.wav  Label:  Applause  Probability:  0.0%
# Burning_short_9.wav  Label:  Bark  Probability:  0.0%
# Burning_short_9.wav  Label:  Bass drum  Probability:  0.0%
# Burning_short_9.wav  Label:  Bass guitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Bathtub (filling or washing)  Probability:  1.3%
# Burning_short_9.wav  Label:  Bell  Probability:  0.1%
# Burning_short_9.wav  Label:  Bicycle  Probability:  1.0%
# Burning_short_9.wav  Label:  Bicycle bell  Probability:  0.0%
# Burning_short_9.wav  Label:  Bird  Probability:  4.9%
# Burning_short_9.wav  Label:  Bird vocalization and bird call and bird song  Probability:  0.8%
# Burning_short_9.wav  Label:  Boat and Water vehicle  Probability:  0.4%
# Burning_short_9.wav  Label:  Boiling  Probability:  0.0%
# Burning_short_9.wav  Label:  Boom  Probability:  0.1%
# Burning_short_9.wav  Label:  Bowed string instrument  Probability:  0.0%
# Burning_short_9.wav  Label:  Brass instrument  Probability:  0.0%
# Burning_short_9.wav  Label:  Breathing  Probability:  0.0%
# Burning_short_9.wav  Label:  Burping and eructation  Probability:  0.0%
# Burning_short_9.wav  Label:  Bus  Probability:  0.2%
# Burning_short_9.wav  Label:  Buzz  Probability:  0.0%
# Burning_short_9.wav  Label:  Camera  Probability:  0.0%
# Burning_short_9.wav  Label:  Car  Probability:  0.1%
# Burning_short_9.wav  Label:  Car passing by  Probability:  0.0%
# Burning_short_9.wav  Label:  Cat  Probability:  0.3%
# Burning_short_9.wav  Label:  Chatter  Probability:  0.2%
# Burning_short_9.wav  Label:  Cheering  Probability:  0.0%
# Burning_short_9.wav  Label:  Chewing and mastication  Probability:  1.3%
# Burning_short_9.wav  Label:  Chicken and rooster  Probability:  0.0%
# Burning_short_9.wav  Label:  Child speech and kid speaking  Probability:  0.0%
# Burning_short_9.wav  Label:  Chime  Probability:  0.0%
# Burning_short_9.wav  Label:  Chink and clink  Probability:  0.0%
# Burning_short_9.wav  Label:  Chirp and tweet  Probability:  0.1%
# Burning_short_9.wav  Label:  Chuckle and chortle  Probability:  0.0%
# Burning_short_9.wav  Label:  Church bell  Probability:  0.1%
# Burning_short_9.wav  Label:  Clapping  Probability:  0.0%
# Burning_short_9.wav  Label:  Clock  Probability:  0.0%
# Burning_short_9.wav  Label:  Coin (dropping)  Probability:  0.0%
# Burning_short_9.wav  Label:  Computer keyboard  Probability:  0.0%
# Burning_short_9.wav  Label:  Conversation  Probability:  0.1%
# Burning_short_9.wav  Label:  Cough  Probability:  0.0%
# Burning_short_9.wav  Label:  Cowbell  Probability:  0.0%
# Burning_short_9.wav  Label:  Crack  Probability:  0.0%
# Burning_short_9.wav  Label:  Crackle  Probability:  0.1%
# Burning_short_9.wav  Label:  Crash cymbal  Probability:  0.0%
# Burning_short_9.wav  Label:  Cricket  Probability:  0.2%
# Burning_short_9.wav  Label:  Crow  Probability:  0.2%
# Burning_short_9.wav  Label:  Crowd  Probability:  0.0%
# Burning_short_9.wav  Label:  Crumpling and crinkling  Probability:  0.4%
# Burning_short_9.wav  Label:  Crushing  Probability:  0.0%
# Burning_short_9.wav  Label:  Crying and sobbing  Probability:  0.0%
# Burning_short_9.wav  Label:  Cupboard open or close  Probability:  0.0%
# Burning_short_9.wav  Label:  Cutlery and silverware  Probability:  0.0%
# Burning_short_9.wav  Label:  Cymbal  Probability:  0.0%
# Burning_short_9.wav  Label:  Dishes and pots and pans  Probability:  0.0%
# Burning_short_9.wav  Label:  Dog  Probability:  0.6%
# Burning_short_9.wav  Label:  Domestic animals and pets  Probability:  1.0%
# Burning_short_9.wav  Label:  Domestic sounds and home sounds  Probability:  19.3%
# Burning_short_9.wav  Label:  Door  Probability:  0.3%
# Burning_short_9.wav  Label:  Doorbell  Probability:  0.0%
# Burning_short_9.wav  Label:  Drawer open or close  Probability:  0.0%
# Burning_short_9.wav  Label:  Drill  Probability:  0.0%
# Burning_short_9.wav  Label:  Drip  Probability:  0.0%
# Burning_short_9.wav  Label:  Drum  Probability:  0.0%
# Burning_short_9.wav  Label:  Drum kit  Probability:  0.0%
# Burning_short_9.wav  Label:  Electric guitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Engine  Probability:  0.1%
# Burning_short_9.wav  Label:  Engine starting  Probability:  0.0%
# Burning_short_9.wav  Label:  Explosion  Probability:  0.0%
# Burning_short_9.wav  Label:  Fart  Probability:  0.0%
# Burning_short_9.wav  Label:  Female singing  Probability:  0.0%
# Burning_short_9.wav  Label:  Female speech and woman speaking  Probability:  0.0%
# Burning_short_9.wav  Label:  Fill (with liquid)  Probability:  0.1%
# Burning_short_9.wav  Label:  Finger snapping  Probability:  0.0%
# Burning_short_9.wav  Label:  Fire  Probability:  0.8%
# Burning_short_9.wav  Label:  Fireworks  Probability:  0.0%
# Burning_short_9.wav  Label:  Fixed-wing aircraft and airplane  Probability:  0.2%
# Burning_short_9.wav  Label:  Fowl  Probability:  0.2%
# Burning_short_9.wav  Label:  Frog  Probability:  0.1%
# Burning_short_9.wav  Label:  Frying (food)  Probability:  0.4%
# Burning_short_9.wav  Label:  Gasp  Probability:  0.0%
# Burning_short_9.wav  Label:  Giggle  Probability:  0.0%
# Burning_short_9.wav  Label:  Glass  Probability:  0.0%
# Burning_short_9.wav  Label:  Glockenspiel  Probability:  0.0%
# Burning_short_9.wav  Label:  Gong  Probability:  0.0%
# Burning_short_9.wav  Label:  Growling  Probability:  0.1%
# Burning_short_9.wav  Label:  Guitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Gull and seagull  Probability:  0.3%
# Burning_short_9.wav  Label:  Gunshot and gunfire  Probability:  0.0%
# Burning_short_9.wav  Label:  Gurgling  Probability:  0.1%
# Burning_short_9.wav  Label:  Hammer  Probability:  0.0%
# Burning_short_9.wav  Label:  Hands  Probability:  0.5%
# Burning_short_9.wav  Label:  Harmonica  Probability:  0.0%
# Burning_short_9.wav  Label:  Harp  Probability:  0.0%
# Burning_short_9.wav  Label:  Hi-hat  Probability:  0.0%
# Burning_short_9.wav  Label:  Hiss  Probability:  0.1%
# Burning_short_9.wav  Label:  Human group actions  Probability:  0.1%
# Burning_short_9.wav  Label:  Human voice  Probability:  1.0%
# Burning_short_9.wav  Label:  Idling  Probability:  0.0%
# Burning_short_9.wav  Label:  Insect  Probability:  1.2%
# Burning_short_9.wav  Label:  Keyboard (musical)  Probability:  0.0%
# Burning_short_9.wav  Label:  Keys jangling  Probability:  0.0%
# Burning_short_9.wav  Label:  Knock  Probability:  0.0%
# Burning_short_9.wav  Label:  Laughter  Probability:  0.0%
# Burning_short_9.wav  Label:  Liquid  Probability:  2.1%
# Burning_short_9.wav  Label:  Livestock and farm animals and working animals  Probability:  1.0%
# Burning_short_9.wav  Label:  Male singing  Probability:  0.0%
# Burning_short_9.wav  Label:  Male speech and man speaking  Probability:  0.0%
# Burning_short_9.wav  Label:  Mallet percussion  Probability:  0.0%
# Burning_short_9.wav  Label:  Marimba and xylophone  Probability:  0.0%
# Burning_short_9.wav  Label:  Mechanical fan  Probability:  0.0%
# Burning_short_9.wav  Label:  Mechanisms  Probability:  0.1%
# Burning_short_9.wav  Label:  Meow  Probability:  0.1%
# Burning_short_9.wav  Label:  Microwave oven  Probability:  0.0%
# Burning_short_9.wav  Label:  Motor vehicle (road)  Probability:  0.7%
# Burning_short_9.wav  Label:  Motorcycle  Probability:  0.0%
# Burning_short_9.wav  Label:  Music  Probability:  0.1%
# Burning_short_9.wav  Label:  Musical instrument  Probability:  0.1%
# Burning_short_9.wav  Label:  Ocean  Probability:  1.3%
# Burning_short_9.wav  Label:  Organ  Probability:  0.0%
# Burning_short_9.wav  Label:  Packing tape and duct tape  Probability:  0.0%
# Burning_short_9.wav  Label:  Percussion  Probability:  0.0%
# Burning_short_9.wav  Label:  Piano  Probability:  0.0%
# Burning_short_9.wav  Label:  Plucked string instrument  Probability:  0.0%
# Burning_short_9.wav  Label:  Pour  Probability:  0.3%
# Burning_short_9.wav  Label:  Power tool  Probability:  0.0%
# Burning_short_9.wav  Label:  Printer  Probability:  0.0%
# Burning_short_9.wav  Label:  Purr  Probability:  0.2%
# Burning_short_9.wav  Label:  Race car and auto racing  Probability:  0.0%
# Burning_short_9.wav  Label:  Rail transport  Probability:  0.1%
# Burning_short_9.wav  Label:  Rain  Probability:  1.5%
# Burning_short_9.wav  Label:  Raindrop  Probability:  0.0%
# Burning_short_9.wav  Label:  Ratchet and pawl  Probability:  0.0%
# Burning_short_9.wav  Label:  Rattle  Probability:  0.0%
# Burning_short_9.wav  Label:  Rattle (instrument)  Probability:  0.0%
# Burning_short_9.wav  Label:  Respiratory sounds  Probability:  0.0%
# Burning_short_9.wav  Label:  Ringtone  Probability:  0.0%
# Burning_short_9.wav  Label:  Run  Probability:  0.0%
# Burning_short_9.wav  Label:  Sawing  Probability:  0.0%
# Burning_short_9.wav  Label:  Scissors  Probability:  0.0%
# Burning_short_9.wav  Label:  Scratching (performance technique)  Probability:  0.0%
# Burning_short_9.wav  Label:  Screaming  Probability:  0.0%
# Burning_short_9.wav  Label:  Screech  Probability:  0.0%
# Burning_short_9.wav  Label:  Shatter  Probability:  0.0%
# Burning_short_9.wav  Label:  Shout  Probability:  0.0%
# Burning_short_9.wav  Label:  Sigh  Probability:  0.0%
# Burning_short_9.wav  Label:  Singing  Probability:  0.6%
# Burning_short_9.wav  Label:  Sink (filling or washing)  Probability:  5.4%
# Burning_short_9.wav  Label:  Siren  Probability:  0.0%
# Burning_short_9.wav  Label:  Skateboard  Probability:  0.0%
# Burning_short_9.wav  Label:  Slam  Probability:  0.0%
# Burning_short_9.wav  Label:  Sliding door  Probability:  0.1%
# Burning_short_9.wav  Label:  Snare drum  Probability:  0.0%
# Burning_short_9.wav  Label:  Sneeze  Probability:  0.0%
# Burning_short_9.wav  Label:  Speech  Probability:  0.2%
# Burning_short_9.wav  Label:  Speech synthesizer  Probability:  0.0%
# Burning_short_9.wav  Label:  Splash and splatter  Probability:  0.7%
# Burning_short_9.wav  Label:  Squeak  Probability:  0.4%
# Burning_short_9.wav  Label:  Stream  Probability:  1.3%
# Burning_short_9.wav  Label:  Strum  Probability:  0.0%
# Burning_short_9.wav  Label:  Subway and metro and underground  Probability:  0.0%
# Burning_short_9.wav  Label:  Tabla  Probability:  0.0%
# Burning_short_9.wav  Label:  Tambourine  Probability:  0.0%
# Burning_short_9.wav  Label:  Tap  Probability:  0.0%
# Burning_short_9.wav  Label:  Tearing  Probability:  1.4%
# Burning_short_9.wav  Label:  Telephone  Probability:  0.1%
# Burning_short_9.wav  Label:  Thump and thud  Probability:  0.0%
# Burning_short_9.wav  Label:  Thunder  Probability:  0.4%
# Burning_short_9.wav  Label:  Thunderstorm  Probability:  0.6%
# Burning_short_9.wav  Label:  Tick  Probability:  0.0%
# Burning_short_9.wav  Label:  Tick-tock  Probability:  0.0%
# Burning_short_9.wav  Label:  Toilet flush  Probability:  0.1%
# Burning_short_9.wav  Label:  Tools  Probability:  0.0%
# Burning_short_9.wav  Label:  Traffic noise and roadway noise  Probability:  0.3%
# Burning_short_9.wav  Label:  Train  Probability:  0.1%
# Burning_short_9.wav  Label:  Trickle and dribble  Probability:  0.4%
# Burning_short_9.wav  Label:  Truck  Probability:  0.1%
# Burning_short_9.wav  Label:  Trumpet  Probability:  0.0%
# Burning_short_9.wav  Label:  Typewriter  Probability:  0.0%
# Burning_short_9.wav  Label:  Typing  Probability:  0.0%
# Burning_short_9.wav  Label:  Vehicle  Probability:  3.3%
# Burning_short_9.wav  Label:  Vehicle horn and car horn and honking  Probability:  0.0%
# Burning_short_9.wav  Label:  Walk and footsteps  Probability:  0.7%
# Burning_short_9.wav  Label:  Water  Probability:  11.2%
# Burning_short_9.wav  Label:  Water tap and faucet  Probability:  5.6%
# Burning_short_9.wav  Label:  Waves and surf  Probability:  0.8%
# Burning_short_9.wav  Label:  Whispering  Probability:  0.5%
# Burning_short_9.wav  Label:  Whoosh and swoosh and swish  Probability:  0.0%
# Burning_short_9.wav  Label:  Wild animals  Probability:  7.0%
# Burning_short_9.wav  Label:  Wind  Probability:  12.0%
# Burning_short_9.wav  Label:  Wind chime  Probability:  0.0%
# Burning_short_9.wav  Label:  Wind instrument and woodwind instrument  Probability:  0.1%
# Burning_short_9.wav  Label:  Wood  Probability:  0.0%
# Burning_short_9.wav  Label:  Writing  Probability:  0.1%
# Burning_short_9.wav  Label:  Yell  Probability:  0.0%
# Burning_short_9.wav  Label:  Zipper (clothing)  Probability:  0.2%
# Burning_short_8.wav  Label:  Accelerating and revving and vroom  Probability:  0.4%
# Burning_short_8.wav  Label:  Accordion  Probability:  0.0%
# Burning_short_8.wav  Label:  Acoustic guitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Aircraft  Probability:  0.0%
# Burning_short_8.wav  Label:  Alarm  Probability:  0.5%
# Burning_short_8.wav  Label:  Animal  Probability:  6.1%
# Burning_short_8.wav  Label:  Applause  Probability:  0.0%
# Burning_short_8.wav  Label:  Bark  Probability:  0.0%
# Burning_short_8.wav  Label:  Bass drum  Probability:  0.0%
# Burning_short_8.wav  Label:  Bass guitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Bathtub (filling or washing)  Probability:  0.1%
# Burning_short_8.wav  Label:  Bell  Probability:  1.1%
# Burning_short_8.wav  Label:  Bicycle  Probability:  1.3%
# Burning_short_8.wav  Label:  Bicycle bell  Probability:  0.0%
# Burning_short_8.wav  Label:  Bird  Probability:  3.7%
# Burning_short_8.wav  Label:  Bird vocalization and bird call and bird song  Probability:  0.2%
# Burning_short_8.wav  Label:  Boat and Water vehicle  Probability:  0.5%
# Burning_short_8.wav  Label:  Boiling  Probability:  0.0%
# Burning_short_8.wav  Label:  Boom  Probability:  0.0%
# Burning_short_8.wav  Label:  Bowed string instrument  Probability:  0.0%
# Burning_short_8.wav  Label:  Brass instrument  Probability:  0.0%
# Burning_short_8.wav  Label:  Breathing  Probability:  0.1%
# Burning_short_8.wav  Label:  Burping and eructation  Probability:  0.0%
# Burning_short_8.wav  Label:  Bus  Probability:  1.5%
# Burning_short_8.wav  Label:  Buzz  Probability:  0.0%
# Burning_short_8.wav  Label:  Camera  Probability:  0.0%
# Burning_short_8.wav  Label:  Car  Probability:  0.7%
# Burning_short_8.wav  Label:  Car passing by  Probability:  0.0%
# Burning_short_8.wav  Label:  Cat  Probability:  0.1%
# Burning_short_8.wav  Label:  Chatter  Probability:  0.1%
# Burning_short_8.wav  Label:  Cheering  Probability:  0.0%
# Burning_short_8.wav  Label:  Chewing and mastication  Probability:  0.1%
# Burning_short_8.wav  Label:  Chicken and rooster  Probability:  0.0%
# Burning_short_8.wav  Label:  Child speech and kid speaking  Probability:  0.0%
# Burning_short_8.wav  Label:  Chime  Probability:  0.2%
# Burning_short_8.wav  Label:  Chink and clink  Probability:  0.2%
# Burning_short_8.wav  Label:  Chirp and tweet  Probability:  0.1%
# Burning_short_8.wav  Label:  Chuckle and chortle  Probability:  0.0%
# Burning_short_8.wav  Label:  Church bell  Probability:  0.1%
# Burning_short_8.wav  Label:  Clapping  Probability:  0.0%
# Burning_short_8.wav  Label:  Clock  Probability:  0.1%
# Burning_short_8.wav  Label:  Coin (dropping)  Probability:  0.3%
# Burning_short_8.wav  Label:  Computer keyboard  Probability:  0.0%
# Burning_short_8.wav  Label:  Conversation  Probability:  0.0%
# Burning_short_8.wav  Label:  Cough  Probability:  0.0%
# Burning_short_8.wav  Label:  Cowbell  Probability:  0.0%
# Burning_short_8.wav  Label:  Crack  Probability:  0.0%
# Burning_short_8.wav  Label:  Crackle  Probability:  0.0%
# Burning_short_8.wav  Label:  Crash cymbal  Probability:  0.0%
# Burning_short_8.wav  Label:  Cricket  Probability:  0.0%
# Burning_short_8.wav  Label:  Crow  Probability:  0.1%
# Burning_short_8.wav  Label:  Crowd  Probability:  0.0%
# Burning_short_8.wav  Label:  Crumpling and crinkling  Probability:  0.0%
# Burning_short_8.wav  Label:  Crushing  Probability:  0.1%
# Burning_short_8.wav  Label:  Crying and sobbing  Probability:  0.0%
# Burning_short_8.wav  Label:  Cupboard open or close  Probability:  0.0%
# Burning_short_8.wav  Label:  Cutlery and silverware  Probability:  0.5%
# Burning_short_8.wav  Label:  Cymbal  Probability:  0.0%
# Burning_short_8.wav  Label:  Dishes and pots and pans  Probability:  0.7%
# Burning_short_8.wav  Label:  Dog  Probability:  0.1%
# Burning_short_8.wav  Label:  Domestic animals and pets  Probability:  0.2%
# Burning_short_8.wav  Label:  Domestic sounds and home sounds  Probability:  34.3%
# Burning_short_8.wav  Label:  Door  Probability:  13.8%
# Burning_short_8.wav  Label:  Doorbell  Probability:  0.1%
# Burning_short_8.wav  Label:  Drawer open or close  Probability:  1.3%
# Burning_short_8.wav  Label:  Drill  Probability:  0.0%
# Burning_short_8.wav  Label:  Drip  Probability:  0.0%
# Burning_short_8.wav  Label:  Drum  Probability:  0.0%
# Burning_short_8.wav  Label:  Drum kit  Probability:  0.0%
# Burning_short_8.wav  Label:  Electric guitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Engine  Probability:  11.5%
# Burning_short_8.wav  Label:  Engine starting  Probability:  2.4%
# Burning_short_8.wav  Label:  Explosion  Probability:  0.1%
# Burning_short_8.wav  Label:  Fart  Probability:  0.0%
# Burning_short_8.wav  Label:  Female singing  Probability:  0.0%
# Burning_short_8.wav  Label:  Female speech and woman speaking  Probability:  0.0%
# Burning_short_8.wav  Label:  Fill (with liquid)  Probability:  0.0%
# Burning_short_8.wav  Label:  Finger snapping  Probability:  0.0%
# Burning_short_8.wav  Label:  Fire  Probability:  0.1%
# Burning_short_8.wav  Label:  Fireworks  Probability:  0.0%
# Burning_short_8.wav  Label:  Fixed-wing aircraft and airplane  Probability:  0.0%
# Burning_short_8.wav  Label:  Fowl  Probability:  0.0%
# Burning_short_8.wav  Label:  Frog  Probability:  0.0%
# Burning_short_8.wav  Label:  Frying (food)  Probability:  0.1%
# Burning_short_8.wav  Label:  Gasp  Probability:  0.0%
# Burning_short_8.wav  Label:  Giggle  Probability:  0.0%
# Burning_short_8.wav  Label:  Glass  Probability:  10.2%
# Burning_short_8.wav  Label:  Glockenspiel  Probability:  0.0%
# Burning_short_8.wav  Label:  Gong  Probability:  0.0%
# Burning_short_8.wav  Label:  Growling  Probability:  0.0%
# Burning_short_8.wav  Label:  Guitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Gull and seagull  Probability:  0.2%
# Burning_short_8.wav  Label:  Gunshot and gunfire  Probability:  0.0%
# Burning_short_8.wav  Label:  Gurgling  Probability:  0.0%
# Burning_short_8.wav  Label:  Hammer  Probability:  0.2%
# Burning_short_8.wav  Label:  Hands  Probability:  0.0%
# Burning_short_8.wav  Label:  Harmonica  Probability:  0.0%
# Burning_short_8.wav  Label:  Harp  Probability:  0.0%
# Burning_short_8.wav  Label:  Hi-hat  Probability:  0.0%
# Burning_short_8.wav  Label:  Hiss  Probability:  0.5%
# Burning_short_8.wav  Label:  Human group actions  Probability:  0.2%
# Burning_short_8.wav  Label:  Human voice  Probability:  0.9%
# Burning_short_8.wav  Label:  Idling  Probability:  0.2%
# Burning_short_8.wav  Label:  Insect  Probability:  0.2%
# Burning_short_8.wav  Label:  Keyboard (musical)  Probability:  0.0%
# Burning_short_8.wav  Label:  Keys jangling  Probability:  2.2%
# Burning_short_8.wav  Label:  Knock  Probability:  0.0%
# Burning_short_8.wav  Label:  Laughter  Probability:  0.1%
# Burning_short_8.wav  Label:  Liquid  Probability:  0.1%
# Burning_short_8.wav  Label:  Livestock and farm animals and working animals  Probability:  0.3%
# Burning_short_8.wav  Label:  Male singing  Probability:  0.0%
# Burning_short_8.wav  Label:  Male speech and man speaking  Probability:  0.1%
# Burning_short_8.wav  Label:  Mallet percussion  Probability:  0.0%
# Burning_short_8.wav  Label:  Marimba and xylophone  Probability:  0.0%
# Burning_short_8.wav  Label:  Mechanical fan  Probability:  0.0%
# Burning_short_8.wav  Label:  Mechanisms  Probability:  1.4%
# Burning_short_8.wav  Label:  Meow  Probability:  0.0%
# Burning_short_8.wav  Label:  Microwave oven  Probability:  0.0%
# Burning_short_8.wav  Label:  Motor vehicle (road)  Probability:  6.3%
# Burning_short_8.wav  Label:  Motorcycle  Probability:  0.2%
# Burning_short_8.wav  Label:  Music  Probability:  0.2%
# Burning_short_8.wav  Label:  Musical instrument  Probability:  0.2%
# Burning_short_8.wav  Label:  Ocean  Probability:  0.1%
# Burning_short_8.wav  Label:  Organ  Probability:  0.0%
# Burning_short_8.wav  Label:  Packing tape and duct tape  Probability:  0.0%
# Burning_short_8.wav  Label:  Percussion  Probability:  0.1%
# Burning_short_8.wav  Label:  Piano  Probability:  0.0%
# Burning_short_8.wav  Label:  Plucked string instrument  Probability:  0.0%
# Burning_short_8.wav  Label:  Pour  Probability:  0.0%
# Burning_short_8.wav  Label:  Power tool  Probability:  0.0%
# Burning_short_8.wav  Label:  Printer  Probability:  0.1%
# Burning_short_8.wav  Label:  Purr  Probability:  0.0%
# Burning_short_8.wav  Label:  Race car and auto racing  Probability:  0.0%
# Burning_short_8.wav  Label:  Rail transport  Probability:  1.6%
# Burning_short_8.wav  Label:  Rain  Probability:  0.1%
# Burning_short_8.wav  Label:  Raindrop  Probability:  0.0%
# Burning_short_8.wav  Label:  Ratchet and pawl  Probability:  0.0%
# Burning_short_8.wav  Label:  Rattle  Probability:  0.1%
# Burning_short_8.wav  Label:  Rattle (instrument)  Probability:  0.0%
# Burning_short_8.wav  Label:  Respiratory sounds  Probability:  0.3%
# Burning_short_8.wav  Label:  Ringtone  Probability:  0.0%
# Burning_short_8.wav  Label:  Run  Probability:  0.0%
# Burning_short_8.wav  Label:  Sawing  Probability:  1.1%
# Burning_short_8.wav  Label:  Scissors  Probability:  0.1%
# Burning_short_8.wav  Label:  Scratching (performance technique)  Probability:  0.0%
# Burning_short_8.wav  Label:  Screaming  Probability:  0.0%
# Burning_short_8.wav  Label:  Screech  Probability:  1.9%
# Burning_short_8.wav  Label:  Shatter  Probability:  2.8%
# Burning_short_8.wav  Label:  Shout  Probability:  0.0%
# Burning_short_8.wav  Label:  Sigh  Probability:  0.0%
# Burning_short_8.wav  Label:  Singing  Probability:  0.3%
# Burning_short_8.wav  Label:  Sink (filling or washing)  Probability:  0.4%
# Burning_short_8.wav  Label:  Siren  Probability:  0.0%
# Burning_short_8.wav  Label:  Skateboard  Probability:  0.0%
# Burning_short_8.wav  Label:  Slam  Probability:  1.1%
# Burning_short_8.wav  Label:  Sliding door  Probability:  8.2%
# Burning_short_8.wav  Label:  Snare drum  Probability:  0.0%
# Burning_short_8.wav  Label:  Sneeze  Probability:  0.1%
# Burning_short_8.wav  Label:  Speech  Probability:  0.1%
# Burning_short_8.wav  Label:  Speech synthesizer  Probability:  0.0%
# Burning_short_8.wav  Label:  Splash and splatter  Probability:  0.0%
# Burning_short_8.wav  Label:  Squeak  Probability:  22.9%
# Burning_short_8.wav  Label:  Stream  Probability:  0.0%
# Burning_short_8.wav  Label:  Strum  Probability:  0.0%
# Burning_short_8.wav  Label:  Subway and metro and underground  Probability:  0.4%
# Burning_short_8.wav  Label:  Tabla  Probability:  0.0%
# Burning_short_8.wav  Label:  Tambourine  Probability:  0.0%
# Burning_short_8.wav  Label:  Tap  Probability:  0.0%
# Burning_short_8.wav  Label:  Tearing  Probability:  0.1%
# Burning_short_8.wav  Label:  Telephone  Probability:  0.1%
# Burning_short_8.wav  Label:  Thump and thud  Probability:  0.4%
# Burning_short_8.wav  Label:  Thunder  Probability:  0.0%
# Burning_short_8.wav  Label:  Thunderstorm  Probability:  0.0%
# Burning_short_8.wav  Label:  Tick  Probability:  0.0%
# Burning_short_8.wav  Label:  Tick-tock  Probability:  0.1%
# Burning_short_8.wav  Label:  Toilet flush  Probability:  0.1%
# Burning_short_8.wav  Label:  Tools  Probability:  1.1%
# Burning_short_8.wav  Label:  Traffic noise and roadway noise  Probability:  0.1%
# Burning_short_8.wav  Label:  Train  Probability:  0.7%
# Burning_short_8.wav  Label:  Trickle and dribble  Probability:  0.0%
# Burning_short_8.wav  Label:  Truck  Probability:  0.6%
# Burning_short_8.wav  Label:  Trumpet  Probability:  0.0%
# Burning_short_8.wav  Label:  Typewriter  Probability:  0.0%
# Burning_short_8.wav  Label:  Typing  Probability:  0.0%
# Burning_short_8.wav  Label:  Vehicle  Probability:  14.9%
# Burning_short_8.wav  Label:  Vehicle horn and car horn and honking  Probability:  0.0%
# Burning_short_8.wav  Label:  Walk and footsteps  Probability:  0.3%
# Burning_short_8.wav  Label:  Water  Probability:  0.3%
# Burning_short_8.wav  Label:  Water tap and faucet  Probability:  0.3%
# Burning_short_8.wav  Label:  Waves and surf  Probability:  0.0%
# Burning_short_8.wav  Label:  Whispering  Probability:  0.0%
# Burning_short_8.wav  Label:  Whoosh and swoosh and swish  Probability:  0.0%
# Burning_short_8.wav  Label:  Wild animals  Probability:  5.6%
# Burning_short_8.wav  Label:  Wind  Probability:  0.7%
# Burning_short_8.wav  Label:  Wind chime  Probability:  0.1%
# Burning_short_8.wav  Label:  Wind instrument and woodwind instrument  Probability:  0.0%
# Burning_short_8.wav  Label:  Wood  Probability:  0.4%
# Burning_short_8.wav  Label:  Writing  Probability:  0.1%
# Burning_short_8.wav  Label:  Yell  Probability:  0.0%
# Burning_short_8.wav  Label:  Zipper (clothing)  Probability:  0.2%
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/fsd-sinet-vgg42-tlpf_aps-1.pb`
# 2023-08-28 13:55:30.880209: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# 2023-08-28 13:55:30.883691: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/fsd-sinet-vgg42-tlpf_aps-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/fsd-sinet-vgg42-tlpf_aps-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/fsd-sinet-vgg42-tlpf_aps-1.pb`
# Burning_short_10.wav  Label:  Accelerating and revving and vroom  Probability:  0.7%
# Burning_short_10.wav  Label:  Accordion  Probability:  0.0%
# Burning_short_10.wav  Label:  Acoustic guitar  Probability:  0.0%
# Burning_short_10.wav  Label:  Aircraft  Probability:  2.6%
# Burning_short_10.wav  Label:  Alarm  Probability:  0.3%
# Burning_short_10.wav  Label:  Animal  Probability:  0.5%
# Burning_short_10.wav  Label:  Applause  Probability:  0.0%
# Burning_short_10.wav  Label:  Bark  Probability:  0.0%
# Burning_short_10.wav  Label:  Bass drum  Probability:  0.0%
# Burning_short_10.wav  Label:  Bass guitar  Probability:  0.0%
# Burning_short_10.wav  Label:  Bathtub (filling or washing)  Probability:  0.1%
# Burning_short_10.wav  Label:  Bell  Probability:  0.3%
# Burning_short_10.wav  Label:  Bicycle  Probability:  4.2%
# Burning_short_10.wav  Label:  Bicycle bell  Probability:  0.0%
# Burning_short_10.wav  Label:  Bird  Probability:  0.7%
# Burning_short_10.wav  Label:  Bird vocalization and bird call and bird song  Probability:  0.2%
# Burning_short_10.wav  Label:  Boat and Water vehicle  Probability:  0.3%
# Burning_short_10.wav  Label:  Boiling  Probability:  0.0%
# Burning_short_10.wav  Label:  Boom  Probability:  0.3%
# Burning_short_10.wav  Label:  Bowed string instrument  Probability:  0.0%
# Burning_short_10.wav  Label:  Brass instrument  Probability:  0.0%
# Burning_short_10.wav  Label:  Breathing  Probability:  0.5%
# Burning_short_10.wav  Label:  Burping and eructation  Probability:  0.0%
# Burning_short_10.wav  Label:  Bus  Probability:  0.1%
# Burning_short_10.wav  Label:  Buzz  Probability:  0.0%
# Burning_short_10.wav  Label:  Camera  Probability:  0.7%
# Burning_short_10.wav  Label:  Car  Probability:  0.4%
# Burning_short_10.wav  Label:  Car passing by  Probability:  0.0%
# Burning_short_10.wav  Label:  Cat  Probability:  0.0%
# Burning_short_10.wav  Label:  Chatter  Probability:  0.0%
# Burning_short_10.wav  Label:  Cheering  Probability:  0.0%
# Burning_short_10.wav  Label:  Chewing and mastication  Probability:  0.1%
# Burning_short_10.wav  Label:  Chicken and rooster  Probability:  0.0%
# Burning_short_10.wav  Label:  Child speech and kid speaking  Probability:  0.0%
# Burning_short_10.wav  Label:  Chime  Probability:  0.0%
# Burning_short_10.wav  Label:  Chink and clink  Probability:  0.0%
# Burning_short_10.wav  Label:  Chirp and tweet  Probability:  0.0%
# Burning_short_10.wav  Label:  Chuckle and chortle  Probability:  0.0%
# Burning_short_10.wav  Label:  Church bell  Probability:  0.0%
# Burning_short_10.wav  Label:  Clapping  Probability:  0.0%
# Burning_short_10.wav  Label:  Clock  Probability:  0.1%
# Burning_short_10.wav  Label:  Coin (dropping)  Probability:  1.2%
# Burning_short_10.wav  Label:  Computer keyboard  Probability:  0.0%
# Burning_short_10.wav  Label:  Conversation  Probability:  0.0%
# Burning_short_10.wav  Label:  Cough  Probability:  0.0%
# Burning_short_10.wav  Label:  Cowbell  Probability:  0.0%
# Burning_short_10.wav  Label:  Crack  Probability:  0.0%
# Burning_short_10.wav  Label:  Crackle  Probability:  0.1%
# Burning_short_10.wav  Label:  Crash cymbal  Probability:  0.0%
# Burning_short_10.wav  Label:  Cricket  Probability:  0.1%
# Burning_short_10.wav  Label:  Crow  Probability:  0.1%
# Burning_short_10.wav  Label:  Crowd  Probability:  0.0%
# Burning_short_10.wav  Label:  Crumpling and crinkling  Probability:  0.2%
# Burning_short_10.wav  Label:  Crushing  Probability:  0.0%
# Burning_short_10.wav  Label:  Crying and sobbing  Probability:  0.0%
# Burning_short_10.wav  Label:  Cupboard open or close  Probability:  0.0%
# Burning_short_10.wav  Label:  Cutlery and silverware  Probability:  0.0%
# Burning_short_10.wav  Label:  Cymbal  Probability:  0.0%
# Burning_short_10.wav  Label:  Dishes and pots and pans  Probability:  0.1%
# Burning_short_10.wav  Label:  Dog  Probability:  0.0%
# Burning_short_10.wav  Label:  Domestic animals and pets  Probability:  0.1%
# Burning_short_10.wav  Label:  Domestic sounds and home sounds  Probability:  9.5%
# Burning_short_10.wav  Label:  Door  Probability:  1.3%
# Burning_short_10.wav  Label:  Doorbell  Probability:  0.0%
# Burning_short_10.wav  Label:  Drawer open or close  Probability:  0.2%
# Burning_short_10.wav  Label:  Drill  Probability:  0.0%
# Burning_short_10.wav  Label:  Drip  Probability:  0.0%
# Burning_short_10.wav  Label:  Drum  Probability:  0.0%
# Burning_short_10.wav  Label:  Drum kit  Probability:  0.0%
# Burning_short_10.wav  Label:  Electric guitar  Probability:  0.0%
# Burning_short_10.wav  Label:  Engine  Probability:  12.5%
# Burning_short_10.wav  Label:  Engine starting  Probability:  0.9%
# Burning_short_10.wav  Label:  Explosion  Probability:  1.6%
# Burning_short_10.wav  Label:  Fart  Probability:  0.0%
# Burning_short_10.wav  Label:  Female singing  Probability:  0.0%
# Burning_short_10.wav  Label:  Female speech and woman speaking  Probability:  0.0%
# Burning_short_10.wav  Label:  Fill (with liquid)  Probability:  0.0%
# Burning_short_10.wav  Label:  Finger snapping  Probability:  0.0%
# Burning_short_10.wav  Label:  Fire  Probability:  0.2%
# Burning_short_10.wav  Label:  Fireworks  Probability:  0.1%
# Burning_short_10.wav  Label:  Fixed-wing aircraft and airplane  Probability:  0.1%
# Burning_short_10.wav  Label:  Fowl  Probability:  0.0%
# Burning_short_10.wav  Label:  Frog  Probability:  0.0%
# Burning_short_10.wav  Label:  Frying (food)  Probability:  0.0%
# Burning_short_10.wav  Label:  Gasp  Probability:  0.0%
# Burning_short_10.wav  Label:  Giggle  Probability:  0.0%
# Burning_short_10.wav  Label:  Glass  Probability:  0.5%
# Burning_short_10.wav  Label:  Glockenspiel  Probability:  0.0%
# Burning_short_10.wav  Label:  Gong  Probability:  0.0%
# Burning_short_10.wav  Label:  Growling  Probability:  0.0%
# Burning_short_10.wav  Label:  Guitar  Probability:  0.1%
# Burning_short_10.wav  Label:  Gull and seagull  Probability:  0.1%
# Burning_short_10.wav  Label:  Gunshot and gunfire  Probability:  0.7%
# Burning_short_10.wav  Label:  Gurgling  Probability:  0.0%
# Burning_short_10.wav  Label:  Hammer  Probability:  0.0%
# Burning_short_10.wav  Label:  Hands  Probability:  0.0%
# Burning_short_10.wav  Label:  Harmonica  Probability:  0.0%
# Burning_short_10.wav  Label:  Harp  Probability:  0.0%
# Burning_short_10.wav  Label:  Hi-hat  Probability:  0.0%
# Burning_short_10.wav  Label:  Hiss  Probability:  0.2%
# Burning_short_10.wav  Label:  Human group actions  Probability:  0.1%
# Burning_short_10.wav  Label:  Human voice  Probability:  0.9%
# Burning_short_10.wav  Label:  Idling  Probability:  2.9%
# Burning_short_10.wav  Label:  Insect  Probability:  0.1%
# Burning_short_10.wav  Label:  Keyboard (musical)  Probability:  0.1%
# Burning_short_10.wav  Label:  Keys jangling  Probability:  0.1%
# Burning_short_10.wav  Label:  Knock  Probability:  0.0%
# Burning_short_10.wav  Label:  Laughter  Probability:  0.0%
# Burning_short_10.wav  Label:  Liquid  Probability:  0.0%
# Burning_short_10.wav  Label:  Livestock and farm animals and working animals  Probability:  0.0%
# Burning_short_10.wav  Label:  Male singing  Probability:  0.0%
# Burning_short_10.wav  Label:  Male speech and man speaking  Probability:  0.2%
# Burning_short_10.wav  Label:  Mallet percussion  Probability:  0.0%
# Burning_short_10.wav  Label:  Marimba and xylophone  Probability:  0.0%
# Burning_short_10.wav  Label:  Mechanical fan  Probability:  0.1%
# Burning_short_10.wav  Label:  Mechanisms  Probability:  8.6%
# Burning_short_10.wav  Label:  Meow  Probability:  0.0%
# Burning_short_10.wav  Label:  Microwave oven  Probability:  0.0%
# Burning_short_10.wav  Label:  Motor vehicle (road)  Probability:  1.2%
# Burning_short_10.wav  Label:  Motorcycle  Probability:  0.1%
# Burning_short_10.wav  Label:  Music  Probability:  0.2%
# Burning_short_10.wav  Label:  Musical instrument  Probability:  0.2%
# Burning_short_10.wav  Label:  Ocean  Probability:  0.2%
# Burning_short_10.wav  Label:  Organ  Probability:  0.0%
# Burning_short_10.wav  Label:  Packing tape and duct tape  Probability:  0.0%
# Burning_short_10.wav  Label:  Percussion  Probability:  0.0%
# Burning_short_10.wav  Label:  Piano  Probability:  0.1%
# Burning_short_10.wav  Label:  Plucked string instrument  Probability:  0.1%
# Burning_short_10.wav  Label:  Pour  Probability:  0.0%
# Burning_short_10.wav  Label:  Power tool  Probability:  0.0%
# Burning_short_10.wav  Label:  Printer  Probability:  0.1%
# Burning_short_10.wav  Label:  Purr  Probability:  0.0%
# Burning_short_10.wav  Label:  Race car and auto racing  Probability:  0.0%
# Burning_short_10.wav  Label:  Rail transport  Probability:  0.2%
# Burning_short_10.wav  Label:  Rain  Probability:  0.1%
# Burning_short_10.wav  Label:  Raindrop  Probability:  0.0%
# Burning_short_10.wav  Label:  Ratchet and pawl  Probability:  0.1%
# Burning_short_10.wav  Label:  Rattle  Probability:  0.5%
# Burning_short_10.wav  Label:  Rattle (instrument)  Probability:  0.0%
# Burning_short_10.wav  Label:  Respiratory sounds  Probability:  0.9%
# Burning_short_10.wav  Label:  Ringtone  Probability:  0.0%
# Burning_short_10.wav  Label:  Run  Probability:  0.0%
# Burning_short_10.wav  Label:  Sawing  Probability:  0.1%
# Burning_short_10.wav  Label:  Scissors  Probability:  0.0%
# Burning_short_10.wav  Label:  Scratching (performance technique)  Probability:  0.0%
# Burning_short_10.wav  Label:  Screaming  Probability:  0.0%
# Burning_short_10.wav  Label:  Screech  Probability:  0.1%
# Burning_short_10.wav  Label:  Shatter  Probability:  0.1%
# Burning_short_10.wav  Label:  Shout  Probability:  0.1%
# Burning_short_10.wav  Label:  Sigh  Probability:  0.0%
# Burning_short_10.wav  Label:  Singing  Probability:  0.1%
# Burning_short_10.wav  Label:  Sink (filling or washing)  Probability:  0.1%
# Burning_short_10.wav  Label:  Siren  Probability:  0.0%
# Burning_short_10.wav  Label:  Skateboard  Probability:  0.0%
# Burning_short_10.wav  Label:  Slam  Probability:  0.3%
# Burning_short_10.wav  Label:  Sliding door  Probability:  0.1%
# Burning_short_10.wav  Label:  Snare drum  Probability:  0.0%
# Burning_short_10.wav  Label:  Sneeze  Probability:  0.1%
# Burning_short_10.wav  Label:  Speech  Probability:  0.5%
# Burning_short_10.wav  Label:  Speech synthesizer  Probability:  0.0%
# Burning_short_10.wav  Label:  Splash and splatter  Probability:  0.0%
# Burning_short_10.wav  Label:  Squeak  Probability:  1.3%
# Burning_short_10.wav  Label:  Stream  Probability:  0.0%
# Burning_short_10.wav  Label:  Strum  Probability:  0.0%
# Burning_short_10.wav  Label:  Subway and metro and underground  Probability:  0.0%
# Burning_short_10.wav  Label:  Tabla  Probability:  0.0%
# Burning_short_10.wav  Label:  Tambourine  Probability:  0.0%
# Burning_short_10.wav  Label:  Tap  Probability:  0.0%
# Burning_short_10.wav  Label:  Tearing  Probability:  0.9%
# Burning_short_10.wav  Label:  Telephone  Probability:  0.1%
# Burning_short_10.wav  Label:  Thump and thud  Probability:  0.2%
# Burning_short_10.wav  Label:  Thunder  Probability:  0.2%
# Burning_short_10.wav  Label:  Thunderstorm  Probability:  0.2%
# Burning_short_10.wav  Label:  Tick  Probability:  0.0%
# Burning_short_10.wav  Label:  Tick-tock  Probability:  0.0%
# Burning_short_10.wav  Label:  Toilet flush  Probability:  0.1%
# Burning_short_10.wav  Label:  Tools  Probability:  0.7%
# Burning_short_10.wav  Label:  Traffic noise and roadway noise  Probability:  0.1%
# Burning_short_10.wav  Label:  Train  Probability:  0.2%
# Burning_short_10.wav  Label:  Trickle and dribble  Probability:  0.0%
# Burning_short_10.wav  Label:  Truck  Probability:  1.9%
# Burning_short_10.wav  Label:  Trumpet  Probability:  0.0%
# Burning_short_10.wav  Label:  Typewriter  Probability:  0.0%
# Burning_short_10.wav  Label:  Typing  Probability:  0.2%
# Burning_short_10.wav  Label:  Vehicle  Probability:  17.5%
# Burning_short_10.wav  Label:  Vehicle horn and car horn and honking  Probability:  0.0%
# Burning_short_10.wav  Label:  Walk and footsteps  Probability:  0.1%
# Burning_short_10.wav  Label:  Water  Probability:  0.4%
# Burning_short_10.wav  Label:  Water tap and faucet  Probability:  0.1%
# Burning_short_10.wav  Label:  Waves and surf  Probability:  0.1%
# Burning_short_10.wav  Label:  Whispering  Probability:  0.0%
# Burning_short_10.wav  Label:  Whoosh and swoosh and swish  Probability:  0.0%
# Burning_short_10.wav  Label:  Wild animals  Probability:  0.6%
# Burning_short_10.wav  Label:  Wind  Probability:  0.8%
# Burning_short_10.wav  Label:  Wind chime  Probability:  0.0%
# Burning_short_10.wav  Label:  Wind instrument and woodwind instrument  Probability:  0.1%
# Burning_short_10.wav  Label:  Wood  Probability:  0.1%
# Burning_short_10.wav  Label:  Writing  Probability:  0.0%
# Burning_short_10.wav  Label:  Yell  Probability:  0.1%
# Burning_short_10.wav  Label:  Zipper (clothing)  Probability:  0.1%
# Burning_short_3.wav  Label:  Accelerating and revving and vroom  Probability:  0.2%
# Burning_short_3.wav  Label:  Accordion  Probability:  0.0%
# Burning_short_3.wav  Label:  Acoustic guitar  Probability:  0.0%
# Burning_short_3.wav  Label:  Aircraft  Probability:  0.8%
# Burning_short_3.wav  Label:  Alarm  Probability:  0.1%
# Burning_short_3.wav  Label:  Animal  Probability:  11.6%
# Burning_short_3.wav  Label:  Applause  Probability:  0.1%
# Burning_short_3.wav  Label:  Bark  Probability:  0.0%
# Burning_short_3.wav  Label:  Bass drum  Probability:  0.0%
# Burning_short_3.wav  Label:  Bass guitar  Probability:  0.0%
# Burning_short_3.wav  Label:  Bathtub (filling or washing)  Probability:  0.0%
# Burning_short_3.wav  Label:  Bell  Probability:  1.2%
# Burning_short_3.wav  Label:  Bicycle  Probability:  0.3%
# Burning_short_3.wav  Label:  Bicycle bell  Probability:  0.0%
# Burning_short_3.wav  Label:  Bird  Probability:  4.1%
# Burning_short_3.wav  Label:  Bird vocalization and bird call and bird song  Probability:  0.3%
# Burning_short_3.wav  Label:  Boat and Water vehicle  Probability:  0.2%
# Burning_short_3.wav  Label:  Boiling  Probability:  0.0%
# Burning_short_3.wav  Label:  Boom  Probability:  0.2%
# Burning_short_3.wav  Label:  Bowed string instrument  Probability:  0.0%
# Burning_short_3.wav  Label:  Brass instrument  Probability:  0.0%
# Burning_short_3.wav  Label:  Breathing  Probability:  0.5%
# Burning_short_3.wav  Label:  Burping and eructation  Probability:  0.0%
# Burning_short_3.wav  Label:  Bus  Probability:  2.7%
# Burning_short_3.wav  Label:  Buzz  Probability:  0.0%
# Burning_short_3.wav  Label:  Camera  Probability:  0.0%
# Burning_short_3.wav  Label:  Car  Probability:  0.6%
# Burning_short_3.wav  Label:  Car passing by  Probability:  0.2%
# Burning_short_3.wav  Label:  Cat  Probability:  0.1%
# Burning_short_3.wav  Label:  Chatter  Probability:  0.0%
# Burning_short_3.wav  Label:  Cheering  Probability:  0.0%
# Burning_short_3.wav  Label:  Chewing and mastication  Probability:  0.1%
# Burning_short_3.wav  Label:  Chicken and rooster  Probability:  0.0%
# Burning_short_3.wav  Label:  Child speech and kid speaking  Probability:  0.0%
# Burning_short_3.wav  Label:  Chime  Probability:  0.3%
# Burning_short_3.wav  Label:  Chink and clink  Probability:  0.5%
# Burning_short_3.wav  Label:  Chirp and tweet  Probability:  0.0%
# Burning_short_3.wav  Label:  Chuckle and chortle  Probability:  0.0%
# Burning_short_3.wav  Label:  Church bell  Probability:  0.1%
# Burning_short_3.wav  Label:  Clapping  Probability:  0.0%
# Burning_short_3.wav  Label:  Clock  Probability:  0.0%
# Burning_short_3.wav  Label:  Coin (dropping)  Probability:  0.2%
# Burning_short_3.wav  Label:  Computer keyboard  Probability:  0.0%
# Burning_short_3.wav  Label:  Conversation  Probability:  0.0%
# Burning_short_3.wav  Label:  Cough  Probability:  0.0%
# Burning_short_3.wav  Label:  Cowbell  Probability:  0.0%
# Burning_short_3.wav  Label:  Crack  Probability:  0.0%
# Burning_short_3.wav  Label:  Crackle  Probability:  0.0%
# Burning_short_3.wav  Label:  Crash cymbal  Probability:  0.0%
# Burning_short_3.wav  Label:  Cricket  Probability:  0.0%
# Burning_short_3.wav  Label:  Crow  Probability:  0.4%
# Burning_short_3.wav  Label:  Crowd  Probability:  0.0%
# Burning_short_3.wav  Label:  Crumpling and crinkling  Probability:  0.0%
# Burning_short_3.wav  Label:  Crushing  Probability:  0.1%
# Burning_short_3.wav  Label:  Crying and sobbing  Probability:  0.0%
# Burning_short_3.wav  Label:  Cupboard open or close  Probability:  0.0%
# Burning_short_3.wav  Label:  Cutlery and silverware  Probability:  0.2%
# Burning_short_3.wav  Label:  Cymbal  Probability:  0.0%
# Burning_short_3.wav  Label:  Dishes and pots and pans  Probability:  0.5%
# Burning_short_3.wav  Label:  Dog  Probability:  0.1%
# Burning_short_3.wav  Label:  Domestic animals and pets  Probability:  0.2%
# Burning_short_3.wav  Label:  Domestic sounds and home sounds  Probability:  15.7%
# Burning_short_3.wav  Label:  Door  Probability:  9.9%
# Burning_short_3.wav  Label:  Doorbell  Probability:  0.0%
# Burning_short_3.wav  Label:  Drawer open or close  Probability:  0.7%
# Burning_short_3.wav  Label:  Drill  Probability:  0.0%
# Burning_short_3.wav  Label:  Drip  Probability:  0.0%
# Burning_short_3.wav  Label:  Drum  Probability:  0.0%
# Burning_short_3.wav  Label:  Drum kit  Probability:  0.0%
# Burning_short_3.wav  Label:  Electric guitar  Probability:  0.0%
# Burning_short_3.wav  Label:  Engine  Probability:  10.0%
# Burning_short_3.wav  Label:  Engine starting  Probability:  1.1%
# Burning_short_3.wav  Label:  Explosion  Probability:  0.3%
# Burning_short_3.wav  Label:  Fart  Probability:  0.0%
# Burning_short_3.wav  Label:  Female singing  Probability:  0.0%
# Burning_short_3.wav  Label:  Female speech and woman speaking  Probability:  0.0%
# Burning_short_3.wav  Label:  Fill (with liquid)  Probability:  0.0%
# Burning_short_3.wav  Label:  Finger snapping  Probability:  0.0%
# Burning_short_3.wav  Label:  Fire  Probability:  0.1%
# Burning_short_3.wav  Label:  Fireworks  Probability:  0.0%
# Burning_short_3.wav  Label:  Fixed-wing aircraft and airplane  Probability:  0.1%
# Burning_short_3.wav  Label:  Fowl  Probability:  0.1%
# Burning_short_3.wav  Label:  Frog  Probability:  0.0%
# Burning_short_3.wav  Label:  Frying (food)  Probability:  0.0%
# Burning_short_3.wav  Label:  Gasp  Probability:  0.0%
# Burning_short_3.wav  Label:  Giggle  Probability:  0.0%
# Burning_short_3.wav  Label:  Glass  Probability:  22.3%
# Burning_short_3.wav  Label:  Glockenspiel  Probability:  0.0%
# Burning_short_3.wav  Label:  Gong  Probability:  0.0%
# Burning_short_3.wav  Label:  Growling  Probability:  0.2%
# Burning_short_3.wav  Label:  Guitar  Probability:  0.0%
# Burning_short_3.wav  Label:  Gull and seagull  Probability:  0.3%
# Burning_short_3.wav  Label:  Gunshot and gunfire  Probability:  0.4%
# Burning_short_3.wav  Label:  Gurgling  Probability:  0.0%
# Burning_short_3.wav  Label:  Hammer  Probability:  0.1%
# Burning_short_3.wav  Label:  Hands  Probability:  0.0%
# Burning_short_3.wav  Label:  Harmonica  Probability:  0.0%
# Burning_short_3.wav  Label:  Harp  Probability:  0.0%
# Burning_short_3.wav  Label:  Hi-hat  Probability:  0.0%
# Burning_short_3.wav  Label:  Hiss  Probability:  0.1%
# Burning_short_3.wav  Label:  Human group actions  Probability:  0.3%
# Burning_short_3.wav  Label:  Human voice  Probability:  0.2%
# Burning_short_3.wav  Label:  Idling  Probability:  0.5%
# Burning_short_3.wav  Label:  Insect  Probability:  0.0%
# Burning_short_3.wav  Label:  Keyboard (musical)  Probability:  0.1%
# Burning_short_3.wav  Label:  Keys jangling  Probability:  0.4%
# Burning_short_3.wav  Label:  Knock  Probability:  0.0%
# Burning_short_3.wav  Label:  Laughter  Probability:  0.1%
# Burning_short_3.wav  Label:  Liquid  Probability:  0.3%
# Burning_short_3.wav  Label:  Livestock and farm animals and working animals  Probability:  2.4%
# Burning_short_3.wav  Label:  Male singing  Probability:  0.0%
# Burning_short_3.wav  Label:  Male speech and man speaking  Probability:  0.0%
# Burning_short_3.wav  Label:  Mallet percussion  Probability:  0.0%
# Burning_short_3.wav  Label:  Marimba and xylophone  Probability:  0.0%
# Burning_short_3.wav  Label:  Mechanical fan  Probability:  0.0%
# Burning_short_3.wav  Label:  Mechanisms  Probability:  1.3%
# Burning_short_3.wav  Label:  Meow  Probability:  0.0%
# Burning_short_3.wav  Label:  Microwave oven  Probability:  0.0%
# Burning_short_3.wav  Label:  Motor vehicle (road)  Probability:  7.0%
# Burning_short_3.wav  Label:  Motorcycle  Probability:  0.2%
# Burning_short_3.wav  Label:  Music  Probability:  0.2%
# Burning_short_3.wav  Label:  Musical instrument  Probability:  0.2%
# Burning_short_3.wav  Label:  Ocean  Probability:  0.8%
# Burning_short_3.wav  Label:  Organ  Probability:  0.0%
# Burning_short_3.wav  Label:  Packing tape and duct tape  Probability:  0.0%
# Burning_short_3.wav  Label:  Percussion  Probability:  0.0%
# Burning_short_3.wav  Label:  Piano  Probability:  0.0%
# Burning_short_3.wav  Label:  Plucked string instrument  Probability:  0.0%
# Burning_short_3.wav  Label:  Pour  Probability:  0.0%
# Burning_short_3.wav  Label:  Power tool  Probability:  0.0%
# Burning_short_3.wav  Label:  Printer  Probability:  0.0%
# Burning_short_3.wav  Label:  Purr  Probability:  0.0%
# Burning_short_3.wav  Label:  Race car and auto racing  Probability:  0.0%
# Burning_short_3.wav  Label:  Rail transport  Probability:  0.3%
# Burning_short_3.wav  Label:  Rain  Probability:  0.1%
# Burning_short_3.wav  Label:  Raindrop  Probability:  0.0%
# Burning_short_3.wav  Label:  Ratchet and pawl  Probability:  0.0%
# Burning_short_3.wav  Label:  Rattle  Probability:  0.1%
# Burning_short_3.wav  Label:  Rattle (instrument)  Probability:  0.0%
# Burning_short_3.wav  Label:  Respiratory sounds  Probability:  0.8%
# Burning_short_3.wav  Label:  Ringtone  Probability:  0.0%
# Burning_short_3.wav  Label:  Run  Probability:  0.1%
# Burning_short_3.wav  Label:  Sawing  Probability:  0.1%
# Burning_short_3.wav  Label:  Scissors  Probability:  0.0%
# Burning_short_3.wav  Label:  Scratching (performance technique)  Probability:  0.0%
# Burning_short_3.wav  Label:  Screaming  Probability:  0.0%
# Burning_short_3.wav  Label:  Screech  Probability:  0.5%
# Burning_short_3.wav  Label:  Shatter  Probability:  3.7%
# Burning_short_3.wav  Label:  Shout  Probability:  0.0%
# Burning_short_3.wav  Label:  Sigh  Probability:  0.0%
# Burning_short_3.wav  Label:  Singing  Probability:  0.1%
# Burning_short_3.wav  Label:  Sink (filling or washing)  Probability:  0.1%
# Burning_short_3.wav  Label:  Siren  Probability:  0.0%
# Burning_short_3.wav  Label:  Skateboard  Probability:  0.0%
# Burning_short_3.wav  Label:  Slam  Probability:  0.6%
# Burning_short_3.wav  Label:  Sliding door  Probability:  6.5%
# Burning_short_3.wav  Label:  Snare drum  Probability:  0.0%
# Burning_short_3.wav  Label:  Sneeze  Probability:  0.0%
# Burning_short_3.wav  Label:  Speech  Probability:  0.0%
# Burning_short_3.wav  Label:  Speech synthesizer  Probability:  0.0%
# Burning_short_3.wav  Label:  Splash and splatter  Probability:  0.0%
# Burning_short_3.wav  Label:  Squeak  Probability:  8.5%
# ...
# Burning_short_6.wav  Label:  Scissors  Probability:  0.0%
# Burning_short_6.wav  Label:  Scratching (performance technique)  Probability:  0.0%
# Burning_short_6.wav  Label:  Screaming  Probability:  0.0%
# Burning_short_6.wav  Label:  Screech  Probability:  0.2%
# Burning_short_6.wav  Label:  Shatter  Probability:  0.0%
# Burning_short_6.wav  Label:  Shout  Probability:  0.0%
# Burning_short_6.wav  Label:  Sigh  Probability:  0.0%
# Burning_short_6.wav  Label:  Singing  Probability:  0.1%
# Burning_short_6.wav  Label:  Sink (filling or washing)  Probability:  2.1%
# Burning_short_6.wav  Label:  Siren  Probability:  0.0%
# Burning_short_6.wav  Label:  Skateboard  Probability:  0.0%
# Burning_short_6.wav  Label:  Slam  Probability:  1.1%
# Burning_short_6.wav  Label:  Sliding door  Probability:  64.5%
# Burning_short_6.wav  Label:  Snare drum  Probability:  0.0%
# Burning_short_6.wav  Label:  Sneeze  Probability:  0.0%
# Burning_short_6.wav  Label:  Speech  Probability:  0.2%
# Burning_short_6.wav  Label:  Speech synthesizer  Probability:  0.0%
# Burning_short_6.wav  Label:  Splash and splatter  Probability:  0.0%
# Burning_short_6.wav  Label:  Squeak  Probability:  3.7%
# Burning_short_6.wav  Label:  Stream  Probability:  0.0%
# Burning_short_6.wav  Label:  Strum  Probability:  0.0%
# Burning_short_6.wav  Label:  Subway and metro and underground  Probability:  2.2%
# Burning_short_6.wav  Label:  Tabla  Probability:  0.0%
# Burning_short_6.wav  Label:  Tambourine  Probability:  0.0%
# Burning_short_6.wav  Label:  Tap  Probability:  0.0%
# Burning_short_6.wav  Label:  Tearing  Probability:  0.0%
# Burning_short_6.wav  Label:  Telephone  Probability:  0.1%
# Burning_short_6.wav  Label:  Thump and thud  Probability:  0.0%
# Burning_short_6.wav  Label:  Thunder  Probability:  0.1%
# Burning_short_6.wav  Label:  Thunderstorm  Probability:  0.2%
# Burning_short_6.wav  Label:  Tick  Probability:  0.0%
# Burning_short_6.wav  Label:  Tick-tock  Probability:  0.0%
# Burning_short_6.wav  Label:  Toilet flush  Probability:  28.2%
# Burning_short_6.wav  Label:  Tools  Probability:  1.1%
# Burning_short_6.wav  Label:  Traffic noise and roadway noise  Probability:  0.1%
# Burning_short_6.wav  Label:  Train  Probability:  2.4%
# Burning_short_6.wav  Label:  Trickle and dribble  Probability:  1.2%
# Burning_short_6.wav  Label:  Truck  Probability:  0.2%
# Burning_short_6.wav  Label:  Trumpet  Probability:  0.0%
# Burning_short_6.wav  Label:  Typewriter  Probability:  0.0%
# Burning_short_6.wav  Label:  Typing  Probability:  0.0%
# Burning_short_6.wav  Label:  Vehicle  Probability:  9.4%
# Burning_short_6.wav  Label:  Vehicle horn and car horn and honking  Probability:  0.0%
# Burning_short_6.wav  Label:  Walk and footsteps  Probability:  0.3%
# Burning_short_6.wav  Label:  Water  Probability:  4.0%
# Burning_short_6.wav  Label:  Water tap and faucet  Probability:  1.0%
# Burning_short_6.wav  Label:  Waves and surf  Probability:  0.2%
# Burning_short_6.wav  Label:  Whispering  Probability:  0.0%
# Burning_short_6.wav  Label:  Whoosh and swoosh and swish  Probability:  0.0%
# Burning_short_6.wav  Label:  Wild animals  Probability:  0.8%
# Burning_short_6.wav  Label:  Wind  Probability:  0.3%
# Burning_short_6.wav  Label:  Wind chime  Probability:  0.0%
# Burning_short_6.wav  Label:  Wind instrument and woodwind instrument  Probability:  0.1%
# Burning_short_6.wav  Label:  Wood  Probability:  0.1%
# Burning_short_6.wav  Label:  Writing  Probability:  0.1%
# Burning_short_6.wav  Label:  Yell  Probability:  0.0%
# Burning_short_6.wav  Label:  Zipper (clothing)  Probability:  0.5%
# Burning_short_7.wav  Label:  Accelerating and revving and vroom  Probability:  0.2%
# Burning_short_7.wav  Label:  Accordion  Probability:  0.0%
# Burning_short_7.wav  Label:  Acoustic guitar  Probability:  0.0%
# Burning_short_7.wav  Label:  Aircraft  Probability:  0.0%
# Burning_short_7.wav  Label:  Alarm  Probability:  1.0%
# Burning_short_7.wav  Label:  Animal  Probability:  21.8%
# Burning_short_7.wav  Label:  Applause  Probability:  0.0%
# Burning_short_7.wav  Label:  Bark  Probability:  0.0%
# Burning_short_7.wav  Label:  Bass drum  Probability:  0.0%
# Burning_short_7.wav  Label:  Bass guitar  Probability:  0.0%
# Burning_short_7.wav  Label:  Bathtub (filling or washing)  Probability:  0.0%
# Burning_short_7.wav  Label:  Bell  Probability:  2.5%
# Burning_short_7.wav  Label:  Bicycle  Probability:  0.2%
# Burning_short_7.wav  Label:  Bicycle bell  Probability:  0.0%
# Burning_short_7.wav  Label:  Bird  Probability:  12.7%
# Burning_short_7.wav  Label:  Bird vocalization and bird call and bird song  Probability:  0.6%
# Burning_short_7.wav  Label:  Boat and Water vehicle  Probability:  1.3%
# Burning_short_7.wav  Label:  Boiling  Probability:  0.0%
# Burning_short_7.wav  Label:  Boom  Probability:  0.7%
# Burning_short_7.wav  Label:  Bowed string instrument  Probability:  0.2%
# Burning_short_7.wav  Label:  Brass instrument  Probability:  0.1%
# Burning_short_7.wav  Label:  Breathing  Probability:  2.6%
# Burning_short_7.wav  Label:  Burping and eructation  Probability:  0.0%
# Burning_short_7.wav  Label:  Bus  Probability:  0.3%
# Burning_short_7.wav  Label:  Buzz  Probability:  0.1%
# Burning_short_7.wav  Label:  Camera  Probability:  0.0%
# Burning_short_7.wav  Label:  Car  Probability:  0.5%
# Burning_short_7.wav  Label:  Car passing by  Probability:  0.0%
# Burning_short_7.wav  Label:  Cat  Probability:  0.0%
# Burning_short_7.wav  Label:  Chatter  Probability:  0.4%
# Burning_short_7.wav  Label:  Cheering  Probability:  0.0%
# Burning_short_7.wav  Label:  Chewing and mastication  Probability:  0.0%
# Burning_short_7.wav  Label:  Chicken and rooster  Probability:  0.0%
# Burning_short_7.wav  Label:  Child speech and kid speaking  Probability:  0.1%
# Burning_short_7.wav  Label:  Chime  Probability:  0.1%
# Burning_short_7.wav  Label:  Chink and clink  Probability:  0.1%
# Burning_short_7.wav  Label:  Chirp and tweet  Probability:  0.4%
# Burning_short_7.wav  Label:  Chuckle and chortle  Probability:  0.0%
# Burning_short_7.wav  Label:  Church bell  Probability:  0.3%
# Burning_short_7.wav  Label:  Clapping  Probability:  0.0%
# Burning_short_7.wav  Label:  Clock  Probability:  0.1%
# Burning_short_7.wav  Label:  Coin (dropping)  Probability:  0.0%
# Burning_short_7.wav  Label:  Computer keyboard  Probability:  0.0%
# Burning_short_7.wav  Label:  Conversation  Probability:  0.0%
# Burning_short_7.wav  Label:  Cough  Probability:  0.1%
# Burning_short_7.wav  Label:  Cowbell  Probability:  0.0%
# Burning_short_7.wav  Label:  Crack  Probability:  0.0%
# Burning_short_7.wav  Label:  Crackle  Probability:  0.0%
# Burning_short_7.wav  Label:  Crash cymbal  Probability:  0.0%
# Burning_short_7.wav  Label:  Cricket  Probability:  0.4%
# Burning_short_7.wav  Label:  Crow  Probability:  0.2%
# Burning_short_7.wav  Label:  Crowd  Probability:  0.2%
# Burning_short_7.wav  Label:  Crumpling and crinkling  Probability:  0.0%
# Burning_short_7.wav  Label:  Crushing  Probability:  0.1%
# Burning_short_7.wav  Label:  Crying and sobbing  Probability:  0.0%
# Burning_short_7.wav  Label:  Cupboard open or close  Probability:  0.1%
# Burning_short_7.wav  Label:  Cutlery and silverware  Probability:  0.1%
# Burning_short_7.wav  Label:  Cymbal  Probability:  0.0%
# Burning_short_7.wav  Label:  Dishes and pots and pans  Probability:  0.2%
# Burning_short_7.wav  Label:  Dog  Probability:  0.3%
# Burning_short_7.wav  Label:  Domestic animals and pets  Probability:  0.2%
# Burning_short_7.wav  Label:  Domestic sounds and home sounds  Probability:  4.8%
# Burning_short_7.wav  Label:  Door  Probability:  4.4%
# Burning_short_7.wav  Label:  Doorbell  Probability:  0.0%
# Burning_short_7.wav  Label:  Drawer open or close  Probability:  0.2%
# Burning_short_7.wav  Label:  Drill  Probability:  0.0%
# Burning_short_7.wav  Label:  Drip  Probability:  0.0%
# Burning_short_7.wav  Label:  Drum  Probability:  0.0%
# Burning_short_7.wav  Label:  Drum kit  Probability:  0.2%
# Burning_short_7.wav  Label:  Electric guitar  Probability:  0.0%
# Burning_short_7.wav  Label:  Engine  Probability:  1.5%
# Burning_short_7.wav  Label:  Engine starting  Probability:  0.2%
# Burning_short_7.wav  Label:  Explosion  Probability:  0.6%
# Burning_short_7.wav  Label:  Fart  Probability:  0.0%
# Burning_short_7.wav  Label:  Female singing  Probability:  0.0%
# Burning_short_7.wav  Label:  Female speech and woman speaking  Probability:  0.1%
# Burning_short_7.wav  Label:  Fill (with liquid)  Probability:  0.0%
# Burning_short_7.wav  Label:  Finger snapping  Probability:  0.0%
# Burning_short_7.wav  Label:  Fire  Probability:  0.2%
# Burning_short_7.wav  Label:  Fireworks  Probability:  0.0%
# Burning_short_7.wav  Label:  Fixed-wing aircraft and airplane  Probability:  0.0%
# Burning_short_7.wav  Label:  Fowl  Probability:  0.1%
# Burning_short_7.wav  Label:  Frog  Probability:  0.0%
# Burning_short_7.wav  Label:  Frying (food)  Probability:  0.0%
# Burning_short_7.wav  Label:  Gasp  Probability:  0.0%
# Burning_short_7.wav  Label:  Giggle  Probability:  0.0%
# Burning_short_7.wav  Label:  Glass  Probability:  5.9%
# Burning_short_7.wav  Label:  Glockenspiel  Probability:  0.0%
# Burning_short_7.wav  Label:  Gong  Probability:  0.0%
# Burning_short_7.wav  Label:  Growling  Probability:  0.0%
# Burning_short_7.wav  Label:  Guitar  Probability:  0.0%
# Burning_short_7.wav  Label:  Gull and seagull  Probability:  0.6%
# Burning_short_7.wav  Label:  Gunshot and gunfire  Probability:  0.0%
# Burning_short_7.wav  Label:  Gurgling  Probability:  0.0%
# Burning_short_7.wav  Label:  Hammer  Probability:  0.5%
# Burning_short_7.wav  Label:  Hands  Probability:  0.0%
# Burning_short_7.wav  Label:  Harmonica  Probability:  0.0%
# Burning_short_7.wav  Label:  Harp  Probability:  0.0%
# Burning_short_7.wav  Label:  Hi-hat  Probability:  0.0%
# Burning_short_7.wav  Label:  Hiss  Probability:  0.2%
# Burning_short_7.wav  Label:  Human group actions  Probability:  0.6%
# Burning_short_7.wav  Label:  Human voice  Probability:  3.8%
# Burning_short_7.wav  Label:  Idling  Probability:  0.0%
# Burning_short_7.wav  Label:  Insect  Probability:  2.3%
# Burning_short_7.wav  Label:  Keyboard (musical)  Probability:  0.2%
# Burning_short_7.wav  Label:  Keys jangling  Probability:  0.2%
# Burning_short_7.wav  Label:  Knock  Probability:  0.0%
# Burning_short_7.wav  Label:  Laughter  Probability:  0.2%
# Burning_short_7.wav  Label:  Liquid  Probability:  0.0%
# Burning_short_7.wav  Label:  Livestock and farm animals and working animals  Probability:  0.2%
# Burning_short_7.wav  Label:  Male singing  Probability:  0.0%
# Burning_short_7.wav  Label:  Male speech and man speaking  Probability:  0.5%
# Burning_short_7.wav  Label:  Mallet percussion  Probability:  0.0%
# Burning_short_7.wav  Label:  Marimba and xylophone  Probability:  0.0%
# Burning_short_7.wav  Label:  Mechanical fan  Probability:  0.0%
# Burning_short_7.wav  Label:  Mechanisms  Probability:  0.3%
# Burning_short_7.wav  Label:  Meow  Probability:  0.0%
# Burning_short_7.wav  Label:  Microwave oven  Probability:  0.0%
# Burning_short_7.wav  Label:  Motor vehicle (road)  Probability:  1.6%
# Burning_short_7.wav  Label:  Motorcycle  Probability:  0.2%
# Burning_short_7.wav  Label:  Music  Probability:  0.7%
# Burning_short_7.wav  Label:  Musical instrument  Probability:  0.7%
# Burning_short_7.wav  Label:  Ocean  Probability:  0.1%
# Burning_short_7.wav  Label:  Organ  Probability:  0.3%
# Burning_short_7.wav  Label:  Packing tape and duct tape  Probability:  0.0%
# Burning_short_7.wav  Label:  Percussion  Probability:  0.1%
# Burning_short_7.wav  Label:  Piano  Probability:  0.0%
# Burning_short_7.wav  Label:  Plucked string instrument  Probability:  0.1%
# Burning_short_7.wav  Label:  Pour  Probability:  0.0%
# Burning_short_7.wav  Label:  Power tool  Probability:  0.0%
# Burning_short_7.wav  Label:  Printer  Probability:  0.0%
# Burning_short_7.wav  Label:  Purr  Probability:  0.0%
# Burning_short_7.wav  Label:  Race car and auto racing  Probability:  0.0%
# Burning_short_7.wav  Label:  Rail transport  Probability:  4.3%
# Burning_short_7.wav  Label:  Rain  Probability:  0.0%
# Burning_short_7.wav  Label:  Raindrop  Probability:  0.0%
# Burning_short_7.wav  Label:  Ratchet and pawl  Probability:  0.0%
# Burning_short_7.wav  Label:  Rattle  Probability:  0.0%
# Burning_short_7.wav  Label:  Rattle (instrument)  Probability:  0.0%
# Burning_short_7.wav  Label:  Respiratory sounds  Probability:  5.2%
# Burning_short_7.wav  Label:  Ringtone  Probability:  0.0%
# Burning_short_7.wav  Label:  Run  Probability:  0.0%
# Burning_short_7.wav  Label:  Sawing  Probability:  0.8%
# Burning_short_7.wav  Label:  Scissors  Probability:  0.0%
# Burning_short_7.wav  Label:  Scratching (performance technique)  Probability:  0.0%
# Burning_short_7.wav  Label:  Screaming  Probability:  0.1%
# Burning_short_7.wav  Label:  Screech  Probability:  3.0%
# Burning_short_7.wav  Label:  Shatter  Probability:  1.2%
# Burning_short_7.wav  Label:  Shout  Probability:  0.0%
# Burning_short_7.wav  Label:  Sigh  Probability:  0.0%
# Burning_short_7.wav  Label:  Singing  Probability:  1.3%
# Burning_short_7.wav  Label:  Sink (filling or washing)  Probability:  0.0%
# Burning_short_7.wav  Label:  Siren  Probability:  0.0%
# Burning_short_7.wav  Label:  Skateboard  Probability:  0.0%
# Burning_short_7.wav  Label:  Slam  Probability:  0.4%
# Burning_short_7.wav  Label:  Sliding door  Probability:  2.1%
# Burning_short_7.wav  Label:  Snare drum  Probability:  0.0%
# Burning_short_7.wav  Label:  Sneeze  Probability:  0.2%
# Burning_short_7.wav  Label:  Speech  Probability:  0.9%
# Burning_short_7.wav  Label:  Speech synthesizer  Probability:  0.0%
# Burning_short_7.wav  Label:  Splash and splatter  Probability:  0.0%
# Burning_short_7.wav  Label:  Squeak  Probability:  3.8%
# Burning_short_7.wav  Label:  Stream  Probability:  0.0%
# Burning_short_7.wav  Label:  Strum  Probability:  0.0%
# Burning_short_7.wav  Label:  Subway and metro and underground  Probability:  1.2%
# Burning_short_7.wav  Label:  Tabla  Probability:  0.0%
# Burning_short_7.wav  Label:  Tambourine  Probability:  0.0%
# Burning_short_7.wav  Label:  Tap  Probability:  0.0%
# Burning_short_7.wav  Label:  Tearing  Probability:  0.0%
# Burning_short_7.wav  Label:  Telephone  Probability:  0.1%
# Burning_short_7.wav  Label:  Thump and thud  Probability:  0.4%
# Burning_short_7.wav  Label:  Thunder  Probability:  0.0%
# Burning_short_7.wav  Label:  Thunderstorm  Probability:  0.0%
# Burning_short_7.wav  Label:  Tick  Probability:  0.0%
# Burning_short_7.wav  Label:  Tick-tock  Probability:  0.0%
# Burning_short_7.wav  Label:  Toilet flush  Probability:  0.0%
# Burning_short_7.wav  Label:  Tools  Probability:  2.3%
# Burning_short_7.wav  Label:  Traffic noise and roadway noise  Probability:  0.5%
# Burning_short_7.wav  Label:  Train  Probability:  1.7%
# Burning_short_7.wav  Label:  Trickle and dribble  Probability:  0.0%
# Burning_short_7.wav  Label:  Truck  Probability:  0.1%
# Burning_short_7.wav  Label:  Trumpet  Probability:  0.0%
# Burning_short_7.wav  Label:  Typewriter  Probability:  0.0%
# Burning_short_7.wav  Label:  Typing  Probability:  0.0%
# Burning_short_7.wav  Label:  Vehicle  Probability:  6.5%
# Burning_short_7.wav  Label:  Vehicle horn and car horn and honking  Probability:  0.0%
# Burning_short_7.wav  Label:  Walk and footsteps  Probability:  0.1%
# Burning_short_7.wav  Label:  Water  Probability:  0.1%
# Burning_short_7.wav  Label:  Water tap and faucet  Probability:  0.0%
# Burning_short_7.wav  Label:  Waves and surf  Probability:  0.0%
# Burning_short_7.wav  Label:  Whispering  Probability:  0.0%
# Burning_short_7.wav  Label:  Whoosh and swoosh and swish  Probability:  0.1%
# Burning_short_7.wav  Label:  Wild animals  Probability:  30.4%
# Burning_short_7.wav  Label:  Wind  Probability:  0.4%
# Burning_short_7.wav  Label:  Wind chime  Probability:  0.0%
# Burning_short_7.wav  Label:  Wind instrument and woodwind instrument  Probability:  0.1%
# Burning_short_7.wav  Label:  Wood  Probability:  0.3%
# Burning_short_7.wav  Label:  Writing  Probability:  0.0%
# Burning_short_7.wav  Label:  Yell  Probability:  0.0%
# Burning_short_7.wav  Label:  Zipper (clothing)  Probability:  0.0%
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/fsd-sinet-vgg42-tlpf_aps-1.pb`

# %% [markdown]
# ## Export Stats

# %% [markdown]
# Finaly, to export the results, we iterate over the list of audio files, extract their classification statistics, and save the statistics to a JSON files. If there is an analysis file dedicated to that audio file with the naming scheme defined bellow, we just add or update the values to the dictionary. At the end, we prompt the os to open the directory containing the files.

# %%
stats_folder = 'Audio Event'
stats_parent = 'FSD-SINet'
processor.export_data(stats, stats_folder, stats_parent)
