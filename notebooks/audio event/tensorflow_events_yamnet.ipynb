# %%
import os, sys
sys.path.append("../../")
from common.base import MetaData, Processor
from common.predictors import TensorflowVGGish

# %% [markdown]
# ## Download Pretrained Models

# %% [markdown]
# In this step, we download and save four machine learning models and their associated metadata files. These models are used for audio feature extraction and classification. We define the URLs for the models and metadata files at the beginning of the code, and we use the `os.path.join()` function to define the file paths where the downloaded files will be saved.
#
# Before downloading the files, we check if they already exist in the specified file paths using the `os.path.exists()` function. If any of the files don't exist, we use the `wget` command to download the files from the URLs and save them to the specified file paths. We use the `-q` option to suppress output from the `wget` command, so the code doesn't print any messages to the console.

# %%
# embedding model
embedding_model_url = ''
embedding_model_json_url = ''
embedding_model_file = os.path.join('../..', 'models', os.path.basename(embedding_model_url))
embedding_model_json = os.path.join('../..', 'models', os.path.basename(embedding_model_json_url))

# classification model
model_url = 'https://essentia.upf.edu/models/audio-event-recognition/yamnet/audioset-yamnet-1.pb'
model_json_url = 'https://essentia.upf.edu/models/audio-event-recognition/yamnet/audioset-yamnet-1.json'
model_file = os.path.join('../..', 'models', os.path.basename(model_url))
model_json = os.path.join('../..', 'models', os.path.basename(model_json_url))

# %%
has_embedding_model = True if(embedding_model_json_url != '' and embedding_model_url != '') else False
if(not os.path.exists(model_json)):
    # !wget -q $model_json_url -P ../../models
if(not os.path.exists(model_file)):
    # !wget -q $model_url -P ../../models
if(has_embedding_model):
    if(not os.path.exists(embedding_model_file)):
        # !wget -q $embedding_model_url -P ../../models
    if(not os.path.exists(embedding_model_json)):
        # !wget -q $embedding_model_json_url -P ../../models

# %% [markdown]
# ## Load Audio
#
# Audio file can be a single file or a directory of sounds

# %%
# open a file dialog to select an audio file or set open_file_dialog to False and set file_path to the audio file
from common.base import file_dialog as fd 
open_file_dialog = False
file_path = '/Users/dtef/Repos/Sync/Audio/Sounds/Sound Libraries/Tef/OK 01/Burning Tornadic Debris Stereo_01/short'
if(open_file_dialog):
    audio_file = fd()
else: audio_file = file_path
    
processor = Processor(audio_file_path=audio_file)
# gets a list of audio files in the selected directory
audio_files = processor.audio_files

# %% [markdown]
# ## Metadata
#
# Next we have to initialise a `MetaData` object with the `model_json` argument, which is assumed to be a file path to a JSON file containing metadata for the TensorFlow model. The `MetaData` object is used to extract the schema and layer information for the model. We do this here since we don't want to initialise a unique instance of the metadata for each audio file we are processing.
#
# The `get_schema()` method of the `MetaData` object is used to extract the schema for the model. The schema is a dictionary that contains information about the model's input and output layers, including their names, shapes, and data types. The schema is printed to the console using the `print()` function.
#
# The `get_layer()` method of the `MetaData` object is used to extract the input and output layers for the model. The `model_input_layer` and `model_output_layer` variables are assigned the input and output layers, respectively. These variables can be used later in the code to feed data into the model and extract the model's output.

# %% [markdown]
# ####    Embeddings metadata

# %%
if(has_embedding_model):
    embeddings_metadata = MetaData(embedding_model_json)
    embeddings_schema = embeddings_metadata.get_schema()

    embeddings_input_layer = embeddings_metadata.get_layer('input')
    print("Detected input layer: ", embeddings_input_layer)
    embeddings_output_layer = embeddings_metadata.get_layer('output', 'embeddings')
    print("Detected output layer: ", embeddings_output_layer)

    print(embeddings_schema)

# %% [markdown]
# ####  Predictor's metadata

# %%
classifier_metadata = MetaData(model_json)
classifier_schema = classifier_metadata.get_schema()

classifier_input_layer = classifier_metadata.get_layer('input')
print("Detected input layer: ", classifier_input_layer)
classifier_output_layer = classifier_metadata.get_layer('output', 'predictions')
print("Detected output layer: ", classifier_output_layer)

print(classifier_schema)
# Out:
# Detected input layer:  melspectrogram
# Detected output layer:  activations
# {'inputs': [{'name': 'melspectrogram', 'type': 'float', 'shape': [96, 64]}], 'outputs': [{'name': 'embeddings', 'type': 'float', 'shape': [1, 1024], 'op': 'fully connected', 'output_purpose': 'embeddings'}, {'name': 'activations', 'type': 'float', 'shape': [1, 521], 'op': 'fully connected', 'output_purpose': 'predictions'}]}

# %% [markdown]
# # Classify

# %% [markdown]
# Since our model is trained on the VGGish embeddings, we need to use the same schema. We could use the `TensorflowPredictVGGish` algorithm because it generates the required mel-spectrogram. This approach won't need any embeddings. But for better learning transfer and noise reduction, the embeddings can be inputed to `TensorflowPredict2D`.
#
# The extractor and classifier used bellow exist in the classifiers.py file. This to reduce the size of the notebook

# %%
classifier = TensorflowVGGish(model_file, classifier_input_layer, classifier_output_layer)
stats = processor.classify_audio(classifier, classifier_metadata)
# Out:
# Burning_short_9.wav  Label:  Speech  Probability:  0.3%
# Burning_short_9.wav  Label:  Child speech, kid speaking  Probability:  0.1%
# Burning_short_9.wav  Label:  Conversation  Probability:  0.0%
# Burning_short_9.wav  Label:  Narration, monologue  Probability:  0.0%
# Burning_short_9.wav  Label:  Babbling  Probability:  0.0%
# Burning_short_9.wav  Label:  Speech synthesizer  Probability:  0.0%
# Burning_short_9.wav  Label:  Shout  Probability:  0.0%
# Burning_short_9.wav  Label:  Bellow  Probability:  0.0%
# Burning_short_9.wav  Label:  Whoop  Probability:  0.0%
# Burning_short_9.wav  Label:  Yell  Probability:  0.0%
# Burning_short_9.wav  Label:  Children shouting  Probability:  0.0%
# Burning_short_9.wav  Label:  Screaming  Probability:  0.0%
# Burning_short_9.wav  Label:  Whispering  Probability:  0.0%
# Burning_short_9.wav  Label:  Laughter  Probability:  0.0%
# Burning_short_9.wav  Label:  Baby laughter  Probability:  0.0%
# Burning_short_9.wav  Label:  Giggle  Probability:  0.0%
# Burning_short_9.wav  Label:  Snicker  Probability:  0.0%
# Burning_short_9.wav  Label:  Belly laugh  Probability:  0.0%
# Burning_short_9.wav  Label:  Chuckle, chortle  Probability:  0.0%
# Burning_short_9.wav  Label:  Crying, sobbing  Probability:  0.0%
# Burning_short_9.wav  Label:  Baby cry, infant cry  Probability:  0.0%
# Burning_short_9.wav  Label:  Whimper  Probability:  0.0%
# Burning_short_9.wav  Label:  Wail, moan  Probability:  0.0%
# Burning_short_9.wav  Label:  Sigh  Probability:  0.0%
# Burning_short_9.wav  Label:  Singing  Probability:  0.0%
# Burning_short_9.wav  Label:  Choir  Probability:  0.0%
# Burning_short_9.wav  Label:  Yodeling  Probability:  0.0%
# Burning_short_9.wav  Label:  Chant  Probability:  0.0%
# Burning_short_9.wav  Label:  Mantra  Probability:  0.0%
# Burning_short_9.wav  Label:  Child singing  Probability:  0.0%
# Burning_short_9.wav  Label:  Synthetic singing  Probability:  0.0%
# Burning_short_9.wav  Label:  Rapping  Probability:  0.0%
# Burning_short_9.wav  Label:  Humming  Probability:  0.0%
# Burning_short_9.wav  Label:  Groan  Probability:  0.0%
# Burning_short_9.wav  Label:  Grunt  Probability:  0.0%
# Burning_short_9.wav  Label:  Whistling  Probability:  0.0%
# Burning_short_9.wav  Label:  Breathing  Probability:  0.0%
# Burning_short_9.wav  Label:  Wheeze  Probability:  0.0%
# Burning_short_9.wav  Label:  Snoring  Probability:  0.0%
# Burning_short_9.wav  Label:  Gasp  Probability:  0.0%
# Burning_short_9.wav  Label:  Pant  Probability:  0.0%
# Burning_short_9.wav  Label:  Snort  Probability:  0.0%
# Burning_short_9.wav  Label:  Cough  Probability:  0.0%
# Burning_short_9.wav  Label:  Throat clearing  Probability:  0.0%
# Burning_short_9.wav  Label:  Sneeze  Probability:  0.0%
# Burning_short_9.wav  Label:  Sniff  Probability:  0.0%
# Burning_short_9.wav  Label:  Run  Probability:  0.0%
# Burning_short_9.wav  Label:  Shuffle  Probability:  0.0%
# Burning_short_9.wav  Label:  Walk, footsteps  Probability:  0.0%
# Burning_short_9.wav  Label:  Chewing, mastication  Probability:  0.0%
# Burning_short_9.wav  Label:  Biting  Probability:  0.0%
# Burning_short_9.wav  Label:  Gargling  Probability:  0.0%
# Burning_short_9.wav  Label:  Stomach rumble  Probability:  0.0%
# Burning_short_9.wav  Label:  Burping, eructation  Probability:  0.0%
# Burning_short_9.wav  Label:  Hiccup  Probability:  0.0%
# Burning_short_9.wav  Label:  Fart  Probability:  0.0%
# Burning_short_9.wav  Label:  Hands  Probability:  0.0%
# Burning_short_9.wav  Label:  Finger snapping  Probability:  0.0%
# Burning_short_9.wav  Label:  Clapping  Probability:  0.0%
# Burning_short_9.wav  Label:  Heart sounds, heartbeat  Probability:  0.0%
# Burning_short_9.wav  Label:  Heart murmur  Probability:  0.0%
# Burning_short_9.wav  Label:  Cheering  Probability:  0.0%
# Burning_short_9.wav  Label:  Applause  Probability:  0.0%
# Burning_short_9.wav  Label:  Chatter  Probability:  0.0%
# Burning_short_9.wav  Label:  Crowd  Probability:  0.0%
# Burning_short_9.wav  Label:  Hubbub, speech noise, speech babble  Probability:  0.0%
# Burning_short_9.wav  Label:  Children playing  Probability:  0.0%
# Burning_short_9.wav  Label:  Animal  Probability:  17.6%
# Burning_short_9.wav  Label:  Domestic animals, pets  Probability:  21.1%
# Burning_short_9.wav  Label:  Dog  Probability:  20.9%
# Burning_short_9.wav  Label:  Bark  Probability:  0.1%
# Burning_short_9.wav  Label:  Yip  Probability:  1.1%
# Burning_short_9.wav  Label:  Howl  Probability:  0.0%
# Burning_short_9.wav  Label:  Bow-wow  Probability:  1.2%
# Burning_short_9.wav  Label:  Growling  Probability:  0.0%
# Burning_short_9.wav  Label:  Whimper (dog)  Probability:  1.3%
# Burning_short_9.wav  Label:  Cat  Probability:  0.0%
# Burning_short_9.wav  Label:  Purr  Probability:  0.0%
# Burning_short_9.wav  Label:  Meow  Probability:  0.0%
# Burning_short_9.wav  Label:  Hiss  Probability:  0.0%
# Burning_short_9.wav  Label:  Caterwaul  Probability:  0.0%
# Burning_short_9.wav  Label:  Livestock, farm animals, working animals  Probability:  0.2%
# Burning_short_9.wav  Label:  Horse  Probability:  0.0%
# Burning_short_9.wav  Label:  Clip-clop  Probability:  0.0%
# Burning_short_9.wav  Label:  Neigh, whinny  Probability:  0.0%
# Burning_short_9.wav  Label:  Cattle, bovinae  Probability:  0.0%
# Burning_short_9.wav  Label:  Moo  Probability:  0.0%
# Burning_short_9.wav  Label:  Cowbell  Probability:  0.0%
# Burning_short_9.wav  Label:  Pig  Probability:  0.1%
# Burning_short_9.wav  Label:  Oink  Probability:  0.0%
# Burning_short_9.wav  Label:  Goat  Probability:  0.0%
# Burning_short_9.wav  Label:  Bleat  Probability:  0.0%
# Burning_short_9.wav  Label:  Sheep  Probability:  0.0%
# Burning_short_9.wav  Label:  Fowl  Probability:  0.1%
# Burning_short_9.wav  Label:  Chicken, rooster  Probability:  0.0%
# Burning_short_9.wav  Label:  Cluck  Probability:  0.0%
# Burning_short_9.wav  Label:  Crowing, cock-a-doodle-doo  Probability:  0.0%
# Burning_short_9.wav  Label:  Turkey  Probability:  0.0%
# Burning_short_9.wav  Label:  Gobble  Probability:  0.0%
# Burning_short_9.wav  Label:  Duck  Probability:  0.1%
# Burning_short_9.wav  Label:  Quack  Probability:  0.0%
# Burning_short_9.wav  Label:  Goose  Probability:  0.0%
# Burning_short_9.wav  Label:  Honk  Probability:  0.0%
# Burning_short_9.wav  Label:  Wild animals  Probability:  0.4%
# Burning_short_9.wav  Label:  Roaring cats (lions, tigers)  Probability:  0.0%
# Burning_short_9.wav  Label:  Roar  Probability:  0.0%
# Burning_short_9.wav  Label:  Bird  Probability:  0.1%
# Burning_short_9.wav  Label:  Bird vocalization, bird call, bird song  Probability:  0.0%
# Burning_short_9.wav  Label:  Chirp, tweet  Probability:  0.0%
# Burning_short_9.wav  Label:  Squawk  Probability:  0.0%
# Burning_short_9.wav  Label:  Pigeon, dove  Probability:  0.0%
# Burning_short_9.wav  Label:  Coo  Probability:  0.0%
# Burning_short_9.wav  Label:  Crow  Probability:  0.0%
# Burning_short_9.wav  Label:  Caw  Probability:  0.0%
# Burning_short_9.wav  Label:  Owl  Probability:  0.0%
# Burning_short_9.wav  Label:  Hoot  Probability:  0.0%
# Burning_short_9.wav  Label:  Bird flight, flapping wings  Probability:  0.0%
# Burning_short_9.wav  Label:  Canidae, dogs, wolves  Probability:  1.6%
# Burning_short_9.wav  Label:  Rodents, rats, mice  Probability:  0.0%
# Burning_short_9.wav  Label:  Mouse  Probability:  0.0%
# Burning_short_9.wav  Label:  Patter  Probability:  0.0%
# Burning_short_9.wav  Label:  Insect  Probability:  0.0%
# Burning_short_9.wav  Label:  Cricket  Probability:  0.0%
# Burning_short_9.wav  Label:  Mosquito  Probability:  0.0%
# Burning_short_9.wav  Label:  Fly, housefly  Probability:  0.0%
# Burning_short_9.wav  Label:  Buzz  Probability:  0.0%
# Burning_short_9.wav  Label:  Bee, wasp, etc.  Probability:  0.0%
# Burning_short_9.wav  Label:  Frog  Probability:  0.0%
# Burning_short_9.wav  Label:  Croak  Probability:  0.0%
# Burning_short_9.wav  Label:  Snake  Probability:  0.0%
# Burning_short_9.wav  Label:  Rattle  Probability:  0.0%
# Burning_short_9.wav  Label:  Whale vocalization  Probability:  0.0%
# Burning_short_9.wav  Label:  Music  Probability:  0.1%
# Burning_short_9.wav  Label:  Musical instrument  Probability:  0.0%
# Burning_short_9.wav  Label:  Plucked string instrument  Probability:  0.0%
# Burning_short_9.wav  Label:  Guitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Electric guitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Bass guitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Acoustic guitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Steel guitar, slide guitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Tapping (guitar technique)  Probability:  0.0%
# Burning_short_9.wav  Label:  Strum  Probability:  0.0%
# Burning_short_9.wav  Label:  Banjo  Probability:  0.0%
# Burning_short_9.wav  Label:  Sitar  Probability:  0.0%
# Burning_short_9.wav  Label:  Mandolin  Probability:  0.0%
# Burning_short_9.wav  Label:  Zither  Probability:  0.0%
# Burning_short_9.wav  Label:  Ukulele  Probability:  0.0%
# Burning_short_9.wav  Label:  Keyboard (musical)  Probability:  0.0%
# Burning_short_9.wav  Label:  Piano  Probability:  0.0%
# Burning_short_9.wav  Label:  Electric piano  Probability:  0.0%
# Burning_short_9.wav  Label:  Organ  Probability:  0.0%
# Burning_short_9.wav  Label:  Electronic organ  Probability:  0.0%
# Burning_short_9.wav  Label:  Hammond organ  Probability:  0.0%
# Burning_short_9.wav  Label:  Synthesizer  Probability:  0.0%
# Burning_short_9.wav  Label:  Sampler  Probability:  0.0%
# Burning_short_9.wav  Label:  Harpsichord  Probability:  0.0%
# Burning_short_9.wav  Label:  Percussion  Probability:  0.0%
# Burning_short_9.wav  Label:  Drum kit  Probability:  0.0%
# Burning_short_9.wav  Label:  Drum machine  Probability:  0.0%
# Burning_short_9.wav  Label:  Drum  Probability:  0.0%
# Burning_short_9.wav  Label:  Snare drum  Probability:  0.0%
# Burning_short_9.wav  Label:  Rimshot  Probability:  0.0%
# Burning_short_9.wav  Label:  Drum roll  Probability:  0.0%
# Burning_short_9.wav  Label:  Bass drum  Probability:  0.0%
# Burning_short_9.wav  Label:  Timpani  Probability:  0.0%
# Burning_short_9.wav  Label:  Tabla  Probability:  0.0%
# Burning_short_9.wav  Label:  Cymbal  Probability:  0.0%
# Burning_short_9.wav  Label:  Hi-hat  Probability:  0.0%
# Burning_short_9.wav  Label:  Wood block  Probability:  0.0%
# Burning_short_9.wav  Label:  Tambourine  Probability:  0.0%
# Burning_short_9.wav  Label:  Rattle (instrument)  Probability:  0.0%
# Burning_short_9.wav  Label:  Maraca  Probability:  0.0%
# Burning_short_9.wav  Label:  Gong  Probability:  0.0%
# Burning_short_9.wav  Label:  Tubular bells  Probability:  0.0%
# Burning_short_9.wav  Label:  Mallet percussion  Probability:  0.0%
# Burning_short_9.wav  Label:  Marimba, xylophone  Probability:  0.0%
# Burning_short_9.wav  Label:  Glockenspiel  Probability:  0.0%
# Burning_short_9.wav  Label:  Vibraphone  Probability:  0.0%
# Burning_short_9.wav  Label:  Steelpan  Probability:  0.0%
# Burning_short_9.wav  Label:  Orchestra  Probability:  0.0%
# Burning_short_9.wav  Label:  Brass instrument  Probability:  0.0%
# Burning_short_9.wav  Label:  French horn  Probability:  0.0%
# Burning_short_9.wav  Label:  Trumpet  Probability:  0.0%
# Burning_short_9.wav  Label:  Trombone  Probability:  0.0%
# Burning_short_9.wav  Label:  Bowed string instrument  Probability:  0.0%
# Burning_short_9.wav  Label:  String section  Probability:  0.0%
# Burning_short_9.wav  Label:  Violin, fiddle  Probability:  0.0%
# Burning_short_9.wav  Label:  Pizzicato  Probability:  0.0%
# Burning_short_9.wav  Label:  Cello  Probability:  0.0%
# Burning_short_9.wav  Label:  Double bass  Probability:  0.0%
# Burning_short_9.wav  Label:  Wind instrument, woodwind instrument  Probability:  0.0%
# Burning_short_9.wav  Label:  Flute  Probability:  0.0%
# Burning_short_9.wav  Label:  Saxophone  Probability:  0.0%
# Burning_short_9.wav  Label:  Clarinet  Probability:  0.0%
# Burning_short_9.wav  Label:  Harp  Probability:  0.0%
# Burning_short_9.wav  Label:  Bell  Probability:  0.0%
# Burning_short_9.wav  Label:  Church bell  Probability:  0.0%
# Burning_short_9.wav  Label:  Jingle bell  Probability:  0.0%
# Burning_short_9.wav  Label:  Bicycle bell  Probability:  0.0%
# Burning_short_9.wav  Label:  Tuning fork  Probability:  0.0%
# Burning_short_9.wav  Label:  Chime  Probability:  0.0%
# Burning_short_9.wav  Label:  Wind chime  Probability:  0.0%
# Burning_short_9.wav  Label:  Change ringing (campanology)  Probability:  0.0%
# Burning_short_9.wav  Label:  Harmonica  Probability:  0.0%
# Burning_short_9.wav  Label:  Accordion  Probability:  0.0%
# Burning_short_9.wav  Label:  Bagpipes  Probability:  0.0%
# Burning_short_9.wav  Label:  Didgeridoo  Probability:  0.0%
# Burning_short_9.wav  Label:  Shofar  Probability:  0.0%
# Burning_short_9.wav  Label:  Theremin  Probability:  0.0%
# Burning_short_9.wav  Label:  Singing bowl  Probability:  0.0%
# Burning_short_9.wav  Label:  Scratching (performance technique)  Probability:  0.0%
# Burning_short_9.wav  Label:  Pop music  Probability:  0.0%
# Burning_short_9.wav  Label:  Hip hop music  Probability:  0.0%
# Burning_short_9.wav  Label:  Beatboxing  Probability:  0.0%
# Burning_short_9.wav  Label:  Rock music  Probability:  0.0%
# Burning_short_9.wav  Label:  Heavy metal  Probability:  0.0%
# Burning_short_9.wav  Label:  Punk rock  Probability:  0.0%
# Burning_short_9.wav  Label:  Grunge  Probability:  0.0%
# Burning_short_9.wav  Label:  Progressive rock  Probability:  0.0%
# Burning_short_9.wav  Label:  Rock and roll  Probability:  0.0%
# Burning_short_9.wav  Label:  Psychedelic rock  Probability:  0.0%
# Burning_short_9.wav  Label:  Rhythm and blues  Probability:  0.0%
# Burning_short_9.wav  Label:  Soul music  Probability:  0.0%
# Burning_short_9.wav  Label:  Reggae  Probability:  0.0%
# Burning_short_9.wav  Label:  Country  Probability:  0.0%
# Burning_short_9.wav  Label:  Swing music  Probability:  0.0%
# Burning_short_9.wav  Label:  Bluegrass  Probability:  0.0%
# Burning_short_9.wav  Label:  Funk  Probability:  0.0%
# Burning_short_9.wav  Label:  Folk music  Probability:  0.0%
# Burning_short_9.wav  Label:  Middle Eastern music  Probability:  0.0%
# Burning_short_9.wav  Label:  Jazz  Probability:  0.0%
# Burning_short_9.wav  Label:  Disco  Probability:  0.0%
# Burning_short_9.wav  Label:  Classical music  Probability:  0.0%
# Burning_short_9.wav  Label:  Opera  Probability:  0.0%
# Burning_short_9.wav  Label:  Electronic music  Probability:  0.0%
# Burning_short_9.wav  Label:  House music  Probability:  0.0%
# Burning_short_9.wav  Label:  Techno  Probability:  0.0%
# Burning_short_9.wav  Label:  Dubstep  Probability:  0.0%
# Burning_short_9.wav  Label:  Drum and bass  Probability:  0.0%
# Burning_short_9.wav  Label:  Electronica  Probability:  0.0%
# Burning_short_9.wav  Label:  Electronic dance music  Probability:  0.0%
# Burning_short_9.wav  Label:  Ambient music  Probability:  0.0%
# Burning_short_9.wav  Label:  Trance music  Probability:  0.0%
# Burning_short_9.wav  Label:  Music of Latin America  Probability:  0.0%
# Burning_short_9.wav  Label:  Salsa music  Probability:  0.0%
# Burning_short_9.wav  Label:  Flamenco  Probability:  0.0%
# Burning_short_9.wav  Label:  Blues  Probability:  0.0%
# Burning_short_9.wav  Label:  Music for children  Probability:  0.0%
# Burning_short_9.wav  Label:  New-age music  Probability:  0.0%
# Burning_short_9.wav  Label:  Vocal music  Probability:  0.0%
# Burning_short_9.wav  Label:  A capella  Probability:  0.0%
# Burning_short_9.wav  Label:  Music of Africa  Probability:  0.0%
# Burning_short_9.wav  Label:  Afrobeat  Probability:  0.0%
# Burning_short_9.wav  Label:  Christian music  Probability:  0.0%
# Burning_short_9.wav  Label:  Gospel music  Probability:  0.0%
# Burning_short_9.wav  Label:  Music of Asia  Probability:  0.0%
# Burning_short_9.wav  Label:  Carnatic music  Probability:  0.0%
# Burning_short_9.wav  Label:  Music of Bollywood  Probability:  0.0%
# Burning_short_9.wav  Label:  Ska  Probability:  0.0%
# Burning_short_9.wav  Label:  Traditional music  Probability:  0.0%
# Burning_short_9.wav  Label:  Independent music  Probability:  0.0%
# Burning_short_9.wav  Label:  Song  Probability:  0.0%
# Burning_short_9.wav  Label:  Background music  Probability:  0.0%
# Burning_short_9.wav  Label:  Theme music  Probability:  0.0%
# Burning_short_9.wav  Label:  Jingle (music)  Probability:  0.0%
# Burning_short_9.wav  Label:  Soundtrack music  Probability:  0.0%
# Burning_short_9.wav  Label:  Lullaby  Probability:  0.0%
# Burning_short_9.wav  Label:  Video game music  Probability:  0.0%
# Burning_short_9.wav  Label:  Christmas music  Probability:  0.0%
# Burning_short_9.wav  Label:  Dance music  Probability:  0.0%
# Burning_short_9.wav  Label:  Wedding music  Probability:  0.0%
# Burning_short_9.wav  Label:  Happy music  Probability:  0.0%
# Burning_short_9.wav  Label:  Sad music  Probability:  0.0%
# Burning_short_9.wav  Label:  Tender music  Probability:  0.0%
# Burning_short_9.wav  Label:  Exciting music  Probability:  0.0%
# Burning_short_9.wav  Label:  Angry music  Probability:  0.0%
# Burning_short_9.wav  Label:  Scary music  Probability:  0.0%
# Burning_short_9.wav  Label:  Wind  Probability:  0.0%
# Burning_short_9.wav  Label:  Rustling leaves  Probability:  0.0%
# Burning_short_9.wav  Label:  Wind noise (microphone)  Probability:  0.0%
# Burning_short_9.wav  Label:  Thunderstorm  Probability:  0.0%
# Burning_short_9.wav  Label:  Thunder  Probability:  0.0%
# Burning_short_9.wav  Label:  Water  Probability:  36.7%
# Burning_short_9.wav  Label:  Rain  Probability:  0.0%
# Burning_short_9.wav  Label:  Raindrop  Probability:  0.0%
# Burning_short_9.wav  Label:  Rain on surface  Probability:  0.0%
# Burning_short_9.wav  Label:  Stream  Probability:  1.2%
# Burning_short_9.wav  Label:  Waterfall  Probability:  0.0%
# Burning_short_9.wav  Label:  Ocean  Probability:  0.1%
# Burning_short_9.wav  Label:  Waves, surf  Probability:  0.0%
# Burning_short_9.wav  Label:  Steam  Probability:  0.0%
# Burning_short_9.wav  Label:  Gurgling  Probability:  1.5%
# Burning_short_9.wav  Label:  Fire  Probability:  0.0%
# Burning_short_9.wav  Label:  Crackle  Probability:  0.0%
# Burning_short_9.wav  Label:  Vehicle  Probability:  0.2%
# Burning_short_9.wav  Label:  Boat, Water vehicle  Probability:  0.1%
# Burning_short_9.wav  Label:  Sailboat, sailing ship  Probability:  0.0%
# Burning_short_9.wav  Label:  Rowboat, canoe, kayak  Probability:  0.0%
# Burning_short_9.wav  Label:  Motorboat, speedboat  Probability:  0.0%
# Burning_short_9.wav  Label:  Ship  Probability:  0.0%
# Burning_short_9.wav  Label:  Motor vehicle (road)  Probability:  0.0%
# Burning_short_9.wav  Label:  Car  Probability:  0.0%
# Burning_short_9.wav  Label:  Vehicle horn, car horn, honking  Probability:  0.0%
# Burning_short_9.wav  Label:  Toot  Probability:  0.0%
# Burning_short_9.wav  Label:  Car alarm  Probability:  0.0%
# Burning_short_9.wav  Label:  Power windows, electric windows  Probability:  0.0%
# Burning_short_9.wav  Label:  Skidding  Probability:  0.0%
# Burning_short_9.wav  Label:  Tire squeal  Probability:  0.0%
# Burning_short_9.wav  Label:  Car passing by  Probability:  0.0%
# Burning_short_9.wav  Label:  Race car, auto racing  Probability:  0.0%
# Burning_short_9.wav  Label:  Truck  Probability:  0.0%
# Burning_short_9.wav  Label:  Air brake  Probability:  0.0%
# Burning_short_9.wav  Label:  Air horn, truck horn  Probability:  0.0%
# Burning_short_9.wav  Label:  Reversing beeps  Probability:  0.0%
# Burning_short_9.wav  Label:  Ice cream truck, ice cream van  Probability:  0.0%
# Burning_short_9.wav  Label:  Bus  Probability:  0.0%
# Burning_short_9.wav  Label:  Emergency vehicle  Probability:  0.0%
# Burning_short_9.wav  Label:  Police car (siren)  Probability:  0.0%
# Burning_short_9.wav  Label:  Ambulance (siren)  Probability:  0.0%
# Burning_short_9.wav  Label:  Fire engine, fire truck (siren)  Probability:  0.0%
# Burning_short_9.wav  Label:  Motorcycle  Probability:  0.0%
# Burning_short_9.wav  Label:  Traffic noise, roadway noise  Probability:  0.0%
# Burning_short_9.wav  Label:  Rail transport  Probability:  0.0%
# Burning_short_9.wav  Label:  Train  Probability:  0.0%
# Burning_short_9.wav  Label:  Train whistle  Probability:  0.0%
# Burning_short_9.wav  Label:  Train horn  Probability:  0.0%
# Burning_short_9.wav  Label:  Railroad car, train wagon  Probability:  0.0%
# Burning_short_9.wav  Label:  Train wheels squealing  Probability:  0.0%
# Burning_short_9.wav  Label:  Subway, metro, underground  Probability:  0.0%
# Burning_short_9.wav  Label:  Aircraft  Probability:  0.0%
# Burning_short_9.wav  Label:  Aircraft engine  Probability:  0.0%
# Burning_short_9.wav  Label:  Jet engine  Probability:  0.0%
# Burning_short_9.wav  Label:  Propeller, airscrew  Probability:  0.0%
# Burning_short_9.wav  Label:  Helicopter  Probability:  0.0%
# Burning_short_9.wav  Label:  Fixed-wing aircraft, airplane  Probability:  0.0%
# Burning_short_9.wav  Label:  Bicycle  Probability:  0.0%
# Burning_short_9.wav  Label:  Skateboard  Probability:  0.0%
# Burning_short_9.wav  Label:  Engine  Probability:  0.0%
# Burning_short_9.wav  Label:  Light engine (high frequency)  Probability:  0.0%
# Burning_short_9.wav  Label:  Dental drill, dentist's drill  Probability:  0.0%
# Burning_short_9.wav  Label:  Lawn mower  Probability:  0.0%
# Burning_short_9.wav  Label:  Chainsaw  Probability:  0.0%
# Burning_short_9.wav  Label:  Medium engine (mid frequency)  Probability:  0.0%
# Burning_short_9.wav  Label:  Heavy engine (low frequency)  Probability:  0.0%
# Burning_short_9.wav  Label:  Engine knocking  Probability:  0.0%
# Burning_short_9.wav  Label:  Engine starting  Probability:  0.0%
# Burning_short_9.wav  Label:  Idling  Probability:  0.0%
# Burning_short_9.wav  Label:  Accelerating, revving, vroom  Probability:  0.0%
# Burning_short_9.wav  Label:  Door  Probability:  0.0%
# Burning_short_9.wav  Label:  Doorbell  Probability:  0.0%
# Burning_short_9.wav  Label:  Ding-dong  Probability:  0.0%
# Burning_short_9.wav  Label:  Sliding door  Probability:  0.0%
# Burning_short_9.wav  Label:  Slam  Probability:  0.0%
# Burning_short_9.wav  Label:  Knock  Probability:  0.0%
# Burning_short_9.wav  Label:  Tap  Probability:  0.0%
# Burning_short_9.wav  Label:  Squeak  Probability:  0.0%
# Burning_short_9.wav  Label:  Cupboard open or close  Probability:  0.0%
# Burning_short_9.wav  Label:  Drawer open or close  Probability:  0.0%
# Burning_short_9.wav  Label:  Dishes, pots, and pans  Probability:  0.0%
# Burning_short_9.wav  Label:  Cutlery, silverware  Probability:  0.0%
# Burning_short_9.wav  Label:  Chopping (food)  Probability:  0.0%
# Burning_short_9.wav  Label:  Frying (food)  Probability:  0.1%
# Burning_short_9.wav  Label:  Microwave oven  Probability:  0.0%
# Burning_short_9.wav  Label:  Blender  Probability:  0.0%
# Burning_short_9.wav  Label:  Water tap, faucet  Probability:  24.7%
# Burning_short_9.wav  Label:  Sink (filling or washing)  Probability:  19.9%
# Burning_short_9.wav  Label:  Bathtub (filling or washing)  Probability:  3.8%
# Burning_short_9.wav  Label:  Hair dryer  Probability:  0.0%
# Burning_short_9.wav  Label:  Toilet flush  Probability:  0.0%
# Burning_short_9.wav  Label:  Toothbrush  Probability:  0.0%
# Burning_short_9.wav  Label:  Electric toothbrush  Probability:  0.0%
# Burning_short_9.wav  Label:  Vacuum cleaner  Probability:  0.0%
# Burning_short_9.wav  Label:  Zipper (clothing)  Probability:  0.0%
# Burning_short_9.wav  Label:  Keys jangling  Probability:  0.0%
# Burning_short_9.wav  Label:  Coin (dropping)  Probability:  0.0%
# Burning_short_9.wav  Label:  Scissors  Probability:  0.0%
# Burning_short_9.wav  Label:  Electric shaver, electric razor  Probability:  0.0%
# Burning_short_9.wav  Label:  Shuffling cards  Probability:  0.0%
# Burning_short_9.wav  Label:  Typing  Probability:  0.0%
# Burning_short_9.wav  Label:  Typewriter  Probability:  0.0%
# Burning_short_9.wav  Label:  Computer keyboard  Probability:  0.0%
# Burning_short_9.wav  Label:  Writing  Probability:  0.0%
# Burning_short_9.wav  Label:  Alarm  Probability:  0.0%
# Burning_short_9.wav  Label:  Telephone  Probability:  0.0%
# Burning_short_9.wav  Label:  Telephone bell ringing  Probability:  0.0%
# Burning_short_9.wav  Label:  Ringtone  Probability:  0.0%
# Burning_short_9.wav  Label:  Telephone dialing, DTMF  Probability:  0.0%
# Burning_short_9.wav  Label:  Dial tone  Probability:  0.0%
# Burning_short_9.wav  Label:  Busy signal  Probability:  0.0%
# Burning_short_9.wav  Label:  Alarm clock  Probability:  0.0%
# Burning_short_9.wav  Label:  Siren  Probability:  0.0%
# Burning_short_9.wav  Label:  Civil defense siren  Probability:  0.0%
# Burning_short_9.wav  Label:  Buzzer  Probability:  0.0%
# Burning_short_9.wav  Label:  Smoke detector, smoke alarm  Probability:  0.0%
# Burning_short_9.wav  Label:  Fire alarm  Probability:  0.0%
# Burning_short_9.wav  Label:  Foghorn  Probability:  0.0%
# Burning_short_9.wav  Label:  Whistle  Probability:  0.0%
# Burning_short_9.wav  Label:  Steam whistle  Probability:  0.0%
# Burning_short_9.wav  Label:  Mechanisms  Probability:  0.0%
# Burning_short_9.wav  Label:  Ratchet, pawl  Probability:  0.0%
# Burning_short_9.wav  Label:  Clock  Probability:  0.0%
# Burning_short_9.wav  Label:  Tick  Probability:  0.0%
# Burning_short_9.wav  Label:  Tick-tock  Probability:  0.0%
# Burning_short_9.wav  Label:  Gears  Probability:  0.0%
# Burning_short_9.wav  Label:  Pulleys  Probability:  0.0%
# Burning_short_9.wav  Label:  Sewing machine  Probability:  0.0%
# Burning_short_9.wav  Label:  Mechanical fan  Probability:  0.0%
# Burning_short_9.wav  Label:  Air conditioning  Probability:  0.0%
# Burning_short_9.wav  Label:  Cash register  Probability:  0.0%
# Burning_short_9.wav  Label:  Printer  Probability:  0.0%
# Burning_short_9.wav  Label:  Camera  Probability:  0.0%
# Burning_short_9.wav  Label:  Single-lens reflex camera  Probability:  0.0%
# Burning_short_9.wav  Label:  Tools  Probability:  0.0%
# Burning_short_9.wav  Label:  Hammer  Probability:  0.0%
# Burning_short_9.wav  Label:  Jackhammer  Probability:  0.0%
# Burning_short_9.wav  Label:  Sawing  Probability:  0.0%
# Burning_short_9.wav  Label:  Filing (rasp)  Probability:  0.0%
# Burning_short_9.wav  Label:  Sanding  Probability:  0.0%
# Burning_short_9.wav  Label:  Power tool  Probability:  0.0%
# Burning_short_9.wav  Label:  Drill  Probability:  0.0%
# Burning_short_9.wav  Label:  Explosion  Probability:  0.0%
# Burning_short_9.wav  Label:  Gunshot, gunfire  Probability:  0.0%
# Burning_short_9.wav  Label:  Machine gun  Probability:  0.0%
# Burning_short_9.wav  Label:  Fusillade  Probability:  0.0%
# Burning_short_9.wav  Label:  Artillery fire  Probability:  0.0%
# Burning_short_9.wav  Label:  Cap gun  Probability:  0.0%
# Burning_short_9.wav  Label:  Fireworks  Probability:  0.0%
# Burning_short_9.wav  Label:  Firecracker  Probability:  0.0%
# Burning_short_9.wav  Label:  Burst, pop  Probability:  0.0%
# Burning_short_9.wav  Label:  Eruption  Probability:  0.0%
# Burning_short_9.wav  Label:  Boom  Probability:  0.0%
# Burning_short_9.wav  Label:  Wood  Probability:  0.0%
# Burning_short_9.wav  Label:  Chop  Probability:  0.0%
# Burning_short_9.wav  Label:  Splinter  Probability:  0.0%
# Burning_short_9.wav  Label:  Crack  Probability:  0.0%
# Burning_short_9.wav  Label:  Glass  Probability:  0.0%
# Burning_short_9.wav  Label:  Chink, clink  Probability:  0.0%
# Burning_short_9.wav  Label:  Shatter  Probability:  0.0%
# Burning_short_9.wav  Label:  Liquid  Probability:  24.6%
# Burning_short_9.wav  Label:  Splash, splatter  Probability:  5.6%
# Burning_short_9.wav  Label:  Slosh  Probability:  2.0%
# Burning_short_9.wav  Label:  Squish  Probability:  0.0%
# Burning_short_9.wav  Label:  Drip  Probability:  0.6%
# Burning_short_9.wav  Label:  Pour  Probability:  20.0%
# Burning_short_9.wav  Label:  Trickle, dribble  Probability:  18.5%
# Burning_short_9.wav  Label:  Gush  Probability:  0.0%
# Burning_short_9.wav  Label:  Fill (with liquid)  Probability:  0.3%
# Burning_short_9.wav  Label:  Spray  Probability:  0.0%
# Burning_short_9.wav  Label:  Pump (liquid)  Probability:  0.0%
# Burning_short_9.wav  Label:  Stir  Probability:  0.0%
# Burning_short_9.wav  Label:  Boiling  Probability:  0.0%
# Burning_short_9.wav  Label:  Sonar  Probability:  0.0%
# Burning_short_9.wav  Label:  Arrow  Probability:  0.0%
# Burning_short_9.wav  Label:  Whoosh, swoosh, swish  Probability:  0.0%
# Burning_short_9.wav  Label:  Thump, thud  Probability:  0.0%
# Burning_short_9.wav  Label:  Thunk  Probability:  0.0%
# Burning_short_9.wav  Label:  Electronic tuner  Probability:  0.0%
# Burning_short_9.wav  Label:  Effects unit  Probability:  0.0%
# Burning_short_9.wav  Label:  Chorus effect  Probability:  0.0%
# Burning_short_9.wav  Label:  Basketball bounce  Probability:  0.0%
# Burning_short_9.wav  Label:  Bang  Probability:  0.0%
# Burning_short_9.wav  Label:  Slap, smack  Probability:  0.0%
# Burning_short_9.wav  Label:  Whack, thwack  Probability:  0.0%
# Burning_short_9.wav  Label:  Smash, crash  Probability:  0.0%
# Burning_short_9.wav  Label:  Breaking  Probability:  0.0%
# Burning_short_9.wav  Label:  Bouncing  Probability:  0.0%
# Burning_short_9.wav  Label:  Whip  Probability:  0.0%
# Burning_short_9.wav  Label:  Flap  Probability:  0.0%
# Burning_short_9.wav  Label:  Scratch  Probability:  0.0%
# Burning_short_9.wav  Label:  Scrape  Probability:  0.0%
# Burning_short_9.wav  Label:  Rub  Probability:  0.0%
# Burning_short_9.wav  Label:  Roll  Probability:  0.0%
# Burning_short_9.wav  Label:  Crushing  Probability:  0.0%
# Burning_short_9.wav  Label:  Crumpling, crinkling  Probability:  0.0%
# Burning_short_9.wav  Label:  Tearing  Probability:  0.0%
# Burning_short_9.wav  Label:  Beep, bleep  Probability:  0.0%
# Burning_short_9.wav  Label:  Ping  Probability:  0.0%
# Burning_short_9.wav  Label:  Ding  Probability:  0.0%
# Burning_short_9.wav  Label:  Clang  Probability:  0.0%
# Burning_short_9.wav  Label:  Squeal  Probability:  0.0%
# Burning_short_9.wav  Label:  Creak  Probability:  0.0%
# Burning_short_9.wav  Label:  Rustle  Probability:  0.0%
# Burning_short_9.wav  Label:  Whir  Probability:  0.0%
# Burning_short_9.wav  Label:  Clatter  Probability:  0.0%
# Burning_short_9.wav  Label:  Sizzle  Probability:  0.0%
# Burning_short_9.wav  Label:  Clicking  Probability:  0.0%
# Burning_short_9.wav  Label:  Clickety-clack  Probability:  0.0%
# Burning_short_9.wav  Label:  Rumble  Probability:  0.0%
# Burning_short_9.wav  Label:  Plop  Probability:  0.0%
# Burning_short_9.wav  Label:  Jingle, tinkle  Probability:  0.0%
# Burning_short_9.wav  Label:  Hum  Probability:  0.0%
# Burning_short_9.wav  Label:  Zing  Probability:  0.0%
# Burning_short_9.wav  Label:  Boing  Probability:  0.0%
# Burning_short_9.wav  Label:  Crunch  Probability:  0.0%
# Burning_short_9.wav  Label:  Silence  Probability:  0.0%
# Burning_short_9.wav  Label:  Sine wave  Probability:  0.0%
# Burning_short_9.wav  Label:  Harmonic  Probability:  0.0%
# Burning_short_9.wav  Label:  Chirp tone  Probability:  0.0%
# Burning_short_9.wav  Label:  Sound effect  Probability:  0.0%
# Burning_short_9.wav  Label:  Pulse  Probability:  0.0%
# Burning_short_9.wav  Label:  Inside, small room  Probability:  2.8%
# Burning_short_9.wav  Label:  Inside, large room or hall  Probability:  0.1%
# Burning_short_9.wav  Label:  Inside, public space  Probability:  0.0%
# Burning_short_9.wav  Label:  Outside, urban or manmade  Probability:  0.1%
# Burning_short_9.wav  Label:  Outside, rural or natural  Probability:  1.7%
# Burning_short_9.wav  Label:  Reverberation  Probability:  0.0%
# Burning_short_9.wav  Label:  Echo  Probability:  0.0%
# Burning_short_9.wav  Label:  Noise  Probability:  0.0%
# Burning_short_9.wav  Label:  Environmental noise  Probability:  0.0%
# Burning_short_9.wav  Label:  Static  Probability:  0.0%
# Burning_short_9.wav  Label:  Mains hum  Probability:  0.0%
# Burning_short_9.wav  Label:  Distortion  Probability:  0.0%
# Burning_short_9.wav  Label:  Sidetone  Probability:  0.0%
# Burning_short_9.wav  Label:  Cacophony  Probability:  0.0%
# Burning_short_9.wav  Label:  White noise  Probability:  0.0%
# Burning_short_9.wav  Label:  Pink noise  Probability:  0.0%
# Burning_short_9.wav  Label:  Throbbing  Probability:  0.0%
# Burning_short_9.wav  Label:  Vibration  Probability:  0.0%
# Burning_short_9.wav  Label:  Television  Probability:  0.0%
# Burning_short_9.wav  Label:  Radio  Probability:  0.0%
# Burning_short_9.wav  Label:  Field recording  Probability:  0.0%
# Burning_short_8.wav  Label:  Speech  Probability:  2.4%
# Burning_short_8.wav  Label:  Child speech, kid speaking  Probability:  0.0%
# Burning_short_8.wav  Label:  Conversation  Probability:  0.0%
# Burning_short_8.wav  Label:  Narration, monologue  Probability:  0.0%
# Burning_short_8.wav  Label:  Babbling  Probability:  0.0%
# Burning_short_8.wav  Label:  Speech synthesizer  Probability:  0.0%
# Burning_short_8.wav  Label:  Shout  Probability:  0.0%
# Burning_short_8.wav  Label:  Bellow  Probability:  0.0%
# Burning_short_8.wav  Label:  Whoop  Probability:  0.0%
# Burning_short_8.wav  Label:  Yell  Probability:  0.0%
# Burning_short_8.wav  Label:  Children shouting  Probability:  0.0%
# Burning_short_8.wav  Label:  Screaming  Probability:  0.0%
# Burning_short_8.wav  Label:  Whispering  Probability:  0.0%
# Burning_short_8.wav  Label:  Laughter  Probability:  0.0%
# Burning_short_8.wav  Label:  Baby laughter  Probability:  0.0%
# Burning_short_8.wav  Label:  Giggle  Probability:  0.0%
# Burning_short_8.wav  Label:  Snicker  Probability:  0.0%
# Burning_short_8.wav  Label:  Belly laugh  Probability:  0.0%
# Burning_short_8.wav  Label:  Chuckle, chortle  Probability:  0.0%
# Burning_short_8.wav  Label:  Crying, sobbing  Probability:  0.0%
# Burning_short_8.wav  Label:  Baby cry, infant cry  Probability:  0.0%
# Burning_short_8.wav  Label:  Whimper  Probability:  0.0%
# Burning_short_8.wav  Label:  Wail, moan  Probability:  0.0%
# Burning_short_8.wav  Label:  Sigh  Probability:  0.0%
# Burning_short_8.wav  Label:  Singing  Probability:  0.0%
# Burning_short_8.wav  Label:  Choir  Probability:  0.0%
# Burning_short_8.wav  Label:  Yodeling  Probability:  0.0%
# Burning_short_8.wav  Label:  Chant  Probability:  0.0%
# Burning_short_8.wav  Label:  Mantra  Probability:  0.0%
# Burning_short_8.wav  Label:  Child singing  Probability:  0.0%
# Burning_short_8.wav  Label:  Synthetic singing  Probability:  0.0%
# Burning_short_8.wav  Label:  Rapping  Probability:  0.0%
# Burning_short_8.wav  Label:  Humming  Probability:  0.0%
# Burning_short_8.wav  Label:  Groan  Probability:  0.0%
# Burning_short_8.wav  Label:  Grunt  Probability:  0.0%
# Burning_short_8.wav  Label:  Whistling  Probability:  0.0%
# Burning_short_8.wav  Label:  Breathing  Probability:  0.0%
# Burning_short_8.wav  Label:  Wheeze  Probability:  0.0%
# Burning_short_8.wav  Label:  Snoring  Probability:  0.0%
# Burning_short_8.wav  Label:  Gasp  Probability:  0.0%
# Burning_short_8.wav  Label:  Pant  Probability:  0.0%
# Burning_short_8.wav  Label:  Snort  Probability:  0.0%
# Burning_short_8.wav  Label:  Cough  Probability:  0.0%
# Burning_short_8.wav  Label:  Throat clearing  Probability:  0.0%
# Burning_short_8.wav  Label:  Sneeze  Probability:  0.0%
# Burning_short_8.wav  Label:  Sniff  Probability:  0.0%
# Burning_short_8.wav  Label:  Run  Probability:  0.1%
# Burning_short_8.wav  Label:  Shuffle  Probability:  0.0%
# Burning_short_8.wav  Label:  Walk, footsteps  Probability:  0.0%
# Burning_short_8.wav  Label:  Chewing, mastication  Probability:  0.0%
# Burning_short_8.wav  Label:  Biting  Probability:  0.0%
# Burning_short_8.wav  Label:  Gargling  Probability:  0.0%
# Burning_short_8.wav  Label:  Stomach rumble  Probability:  0.0%
# Burning_short_8.wav  Label:  Burping, eructation  Probability:  0.0%
# Burning_short_8.wav  Label:  Hiccup  Probability:  0.0%
# Burning_short_8.wav  Label:  Fart  Probability:  0.0%
# Burning_short_8.wav  Label:  Hands  Probability:  0.0%
# Burning_short_8.wav  Label:  Finger snapping  Probability:  0.0%
# Burning_short_8.wav  Label:  Clapping  Probability:  0.0%
# Burning_short_8.wav  Label:  Heart sounds, heartbeat  Probability:  0.0%
# Burning_short_8.wav  Label:  Heart murmur  Probability:  0.0%
# Burning_short_8.wav  Label:  Cheering  Probability:  0.0%
# Burning_short_8.wav  Label:  Applause  Probability:  0.0%
# Burning_short_8.wav  Label:  Chatter  Probability:  0.0%
# Burning_short_8.wav  Label:  Crowd  Probability:  0.0%
# Burning_short_8.wav  Label:  Hubbub, speech noise, speech babble  Probability:  0.0%
# Burning_short_8.wav  Label:  Children playing  Probability:  0.0%
# Burning_short_8.wav  Label:  Animal  Probability:  2.9%
# Burning_short_8.wav  Label:  Domestic animals, pets  Probability:  0.3%
# Burning_short_8.wav  Label:  Dog  Probability:  0.2%
# Burning_short_8.wav  Label:  Bark  Probability:  0.0%
# Burning_short_8.wav  Label:  Yip  Probability:  0.0%
# Burning_short_8.wav  Label:  Howl  Probability:  0.0%
# Burning_short_8.wav  Label:  Bow-wow  Probability:  0.0%
# Burning_short_8.wav  Label:  Growling  Probability:  0.0%
# Burning_short_8.wav  Label:  Whimper (dog)  Probability:  0.0%
# Burning_short_8.wav  Label:  Cat  Probability:  0.0%
# Burning_short_8.wav  Label:  Purr  Probability:  0.0%
# Burning_short_8.wav  Label:  Meow  Probability:  0.0%
# Burning_short_8.wav  Label:  Hiss  Probability:  0.5%
# Burning_short_8.wav  Label:  Caterwaul  Probability:  0.0%
# Burning_short_8.wav  Label:  Livestock, farm animals, working animals  Probability:  0.4%
# Burning_short_8.wav  Label:  Horse  Probability:  0.5%
# Burning_short_8.wav  Label:  Clip-clop  Probability:  0.2%
# Burning_short_8.wav  Label:  Neigh, whinny  Probability:  0.1%
# Burning_short_8.wav  Label:  Cattle, bovinae  Probability:  0.0%
# Burning_short_8.wav  Label:  Moo  Probability:  0.0%
# Burning_short_8.wav  Label:  Cowbell  Probability:  0.0%
# Burning_short_8.wav  Label:  Pig  Probability:  0.1%
# Burning_short_8.wav  Label:  Oink  Probability:  0.0%
# Burning_short_8.wav  Label:  Goat  Probability:  0.1%
# Burning_short_8.wav  Label:  Bleat  Probability:  0.0%
# Burning_short_8.wav  Label:  Sheep  Probability:  0.1%
# Burning_short_8.wav  Label:  Fowl  Probability:  0.1%
# Burning_short_8.wav  Label:  Chicken, rooster  Probability:  0.0%
# Burning_short_8.wav  Label:  Cluck  Probability:  0.0%
# Burning_short_8.wav  Label:  Crowing, cock-a-doodle-doo  Probability:  0.0%
# Burning_short_8.wav  Label:  Turkey  Probability:  0.0%
# Burning_short_8.wav  Label:  Gobble  Probability:  0.0%
# Burning_short_8.wav  Label:  Duck  Probability:  0.0%
# Burning_short_8.wav  Label:  Quack  Probability:  0.0%
# Burning_short_8.wav  Label:  Goose  Probability:  0.0%
# Burning_short_8.wav  Label:  Honk  Probability:  0.0%
# Burning_short_8.wav  Label:  Wild animals  Probability:  1.7%
# Burning_short_8.wav  Label:  Roaring cats (lions, tigers)  Probability:  0.2%
# Burning_short_8.wav  Label:  Roar  Probability:  0.0%
# Burning_short_8.wav  Label:  Bird  Probability:  1.0%
# Burning_short_8.wav  Label:  Bird vocalization, bird call, bird song  Probability:  0.4%
# Burning_short_8.wav  Label:  Chirp, tweet  Probability:  0.2%
# Burning_short_8.wav  Label:  Squawk  Probability:  0.0%
# Burning_short_8.wav  Label:  Pigeon, dove  Probability:  0.2%
# Burning_short_8.wav  Label:  Coo  Probability:  0.1%
# Burning_short_8.wav  Label:  Crow  Probability:  0.0%
# Burning_short_8.wav  Label:  Caw  Probability:  0.0%
# Burning_short_8.wav  Label:  Owl  Probability:  0.1%
# Burning_short_8.wav  Label:  Hoot  Probability:  0.0%
# Burning_short_8.wav  Label:  Bird flight, flapping wings  Probability:  0.0%
# Burning_short_8.wav  Label:  Canidae, dogs, wolves  Probability:  0.0%
# Burning_short_8.wav  Label:  Rodents, rats, mice  Probability:  0.0%
# Burning_short_8.wav  Label:  Mouse  Probability:  0.0%
# Burning_short_8.wav  Label:  Patter  Probability:  0.0%
# Burning_short_8.wav  Label:  Insect  Probability:  0.4%
# Burning_short_8.wav  Label:  Cricket  Probability:  0.2%
# Burning_short_8.wav  Label:  Mosquito  Probability:  0.0%
# Burning_short_8.wav  Label:  Fly, housefly  Probability:  0.0%
# Burning_short_8.wav  Label:  Buzz  Probability:  0.1%
# Burning_short_8.wav  Label:  Bee, wasp, etc.  Probability:  0.0%
# Burning_short_8.wav  Label:  Frog  Probability:  0.2%
# Burning_short_8.wav  Label:  Croak  Probability:  0.0%
# Burning_short_8.wav  Label:  Snake  Probability:  2.1%
# Burning_short_8.wav  Label:  Rattle  Probability:  2.7%
# Burning_short_8.wav  Label:  Whale vocalization  Probability:  0.0%
# Burning_short_8.wav  Label:  Music  Probability:  1.7%
# Burning_short_8.wav  Label:  Musical instrument  Probability:  0.1%
# Burning_short_8.wav  Label:  Plucked string instrument  Probability:  0.0%
# Burning_short_8.wav  Label:  Guitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Electric guitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Bass guitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Acoustic guitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Steel guitar, slide guitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Tapping (guitar technique)  Probability:  0.0%
# Burning_short_8.wav  Label:  Strum  Probability:  0.0%
# Burning_short_8.wav  Label:  Banjo  Probability:  0.0%
# Burning_short_8.wav  Label:  Sitar  Probability:  0.0%
# Burning_short_8.wav  Label:  Mandolin  Probability:  0.0%
# Burning_short_8.wav  Label:  Zither  Probability:  0.0%
# Burning_short_8.wav  Label:  Ukulele  Probability:  0.0%
# Burning_short_8.wav  Label:  Keyboard (musical)  Probability:  0.0%
# Burning_short_8.wav  Label:  Piano  Probability:  0.0%
# Burning_short_8.wav  Label:  Electric piano  Probability:  0.0%
# Burning_short_8.wav  Label:  Organ  Probability:  0.0%
# Burning_short_8.wav  Label:  Electronic organ  Probability:  0.0%
# Burning_short_8.wav  Label:  Hammond organ  Probability:  0.0%
# Burning_short_8.wav  Label:  Synthesizer  Probability:  0.0%
# Burning_short_8.wav  Label:  Sampler  Probability:  0.0%
# Burning_short_8.wav  Label:  Harpsichord  Probability:  0.0%
# Burning_short_8.wav  Label:  Percussion  Probability:  0.1%
# Burning_short_8.wav  Label:  Drum kit  Probability:  0.0%
# Burning_short_8.wav  Label:  Drum machine  Probability:  0.0%
# Burning_short_8.wav  Label:  Drum  Probability:  0.0%
# Burning_short_8.wav  Label:  Snare drum  Probability:  0.0%
# Burning_short_8.wav  Label:  Rimshot  Probability:  0.0%
# Burning_short_8.wav  Label:  Drum roll  Probability:  0.0%
# Burning_short_8.wav  Label:  Bass drum  Probability:  0.0%
# Burning_short_8.wav  Label:  Timpani  Probability:  0.0%
# Burning_short_8.wav  Label:  Tabla  Probability:  0.0%
# Burning_short_8.wav  Label:  Cymbal  Probability:  0.0%
# Burning_short_8.wav  Label:  Hi-hat  Probability:  0.0%
# Burning_short_8.wav  Label:  Wood block  Probability:  0.0%
# Burning_short_8.wav  Label:  Tambourine  Probability:  0.0%
# Burning_short_8.wav  Label:  Rattle (instrument)  Probability:  0.0%
# Burning_short_8.wav  Label:  Maraca  Probability:  0.0%
# Burning_short_8.wav  Label:  Gong  Probability:  0.0%
# Burning_short_8.wav  Label:  Tubular bells  Probability:  0.0%
# Burning_short_8.wav  Label:  Mallet percussion  Probability:  0.0%
# Burning_short_8.wav  Label:  Marimba, xylophone  Probability:  0.0%
# Burning_short_8.wav  Label:  Glockenspiel  Probability:  0.0%
# Burning_short_8.wav  Label:  Vibraphone  Probability:  0.0%
# Burning_short_8.wav  Label:  Steelpan  Probability:  0.0%
# Burning_short_8.wav  Label:  Orchestra  Probability:  0.0%
# Burning_short_8.wav  Label:  Brass instrument  Probability:  0.0%
# Burning_short_8.wav  Label:  French horn  Probability:  0.0%
# Burning_short_8.wav  Label:  Trumpet  Probability:  0.0%
# Burning_short_8.wav  Label:  Trombone  Probability:  0.0%
# Burning_short_8.wav  Label:  Bowed string instrument  Probability:  0.0%
# Burning_short_8.wav  Label:  String section  Probability:  0.0%
# Burning_short_8.wav  Label:  Violin, fiddle  Probability:  0.0%
# Burning_short_8.wav  Label:  Pizzicato  Probability:  0.0%
# Burning_short_8.wav  Label:  Cello  Probability:  0.0%
# Burning_short_8.wav  Label:  Double bass  Probability:  0.0%
# Burning_short_8.wav  Label:  Wind instrument, woodwind instrument  Probability:  0.0%
# Burning_short_8.wav  Label:  Flute  Probability:  0.0%
# Burning_short_8.wav  Label:  Saxophone  Probability:  0.0%
# Burning_short_8.wav  Label:  Clarinet  Probability:  0.0%
# Burning_short_8.wav  Label:  Harp  Probability:  0.0%
# Burning_short_8.wav  Label:  Bell  Probability:  0.0%
# Burning_short_8.wav  Label:  Church bell  Probability:  0.0%
# Burning_short_8.wav  Label:  Jingle bell  Probability:  0.1%
# Burning_short_8.wav  Label:  Bicycle bell  Probability:  0.0%
# Burning_short_8.wav  Label:  Tuning fork  Probability:  0.0%
# Burning_short_8.wav  Label:  Chime  Probability:  0.0%
# Burning_short_8.wav  Label:  Wind chime  Probability:  0.0%
# Burning_short_8.wav  Label:  Change ringing (campanology)  Probability:  0.0%
# Burning_short_8.wav  Label:  Harmonica  Probability:  0.0%
# Burning_short_8.wav  Label:  Accordion  Probability:  0.0%
# Burning_short_8.wav  Label:  Bagpipes  Probability:  0.0%
# Burning_short_8.wav  Label:  Didgeridoo  Probability:  0.0%
# Burning_short_8.wav  Label:  Shofar  Probability:  0.0%
# Burning_short_8.wav  Label:  Theremin  Probability:  0.0%
# Burning_short_8.wav  Label:  Singing bowl  Probability:  0.0%
# Burning_short_8.wav  Label:  Scratching (performance technique)  Probability:  0.0%
# Burning_short_8.wav  Label:  Pop music  Probability:  0.0%
# Burning_short_8.wav  Label:  Hip hop music  Probability:  0.0%
# Burning_short_8.wav  Label:  Beatboxing  Probability:  0.0%
# Burning_short_8.wav  Label:  Rock music  Probability:  0.0%
# Burning_short_8.wav  Label:  Heavy metal  Probability:  0.0%
# Burning_short_8.wav  Label:  Punk rock  Probability:  0.0%
# Burning_short_8.wav  Label:  Grunge  Probability:  0.0%
# Burning_short_8.wav  Label:  Progressive rock  Probability:  0.0%
# Burning_short_8.wav  Label:  Rock and roll  Probability:  0.0%
# Burning_short_8.wav  Label:  Psychedelic rock  Probability:  0.0%
# Burning_short_8.wav  Label:  Rhythm and blues  Probability:  0.0%
# Burning_short_8.wav  Label:  Soul music  Probability:  0.0%
# Burning_short_8.wav  Label:  Reggae  Probability:  0.0%
# Burning_short_8.wav  Label:  Country  Probability:  0.0%
# Burning_short_8.wav  Label:  Swing music  Probability:  0.0%
# Burning_short_8.wav  Label:  Bluegrass  Probability:  0.0%
# Burning_short_8.wav  Label:  Funk  Probability:  0.0%
# Burning_short_8.wav  Label:  Folk music  Probability:  0.0%
# Burning_short_8.wav  Label:  Middle Eastern music  Probability:  0.0%
# Burning_short_8.wav  Label:  Jazz  Probability:  0.0%
# Burning_short_8.wav  Label:  Disco  Probability:  0.0%
# Burning_short_8.wav  Label:  Classical music  Probability:  0.0%
# Burning_short_8.wav  Label:  Opera  Probability:  0.0%
# Burning_short_8.wav  Label:  Electronic music  Probability:  0.1%
# Burning_short_8.wav  Label:  House music  Probability:  0.0%
# Burning_short_8.wav  Label:  Techno  Probability:  0.0%
# Burning_short_8.wav  Label:  Dubstep  Probability:  0.0%
# Burning_short_8.wav  Label:  Drum and bass  Probability:  0.0%
# Burning_short_8.wav  Label:  Electronica  Probability:  0.0%
# Burning_short_8.wav  Label:  Electronic dance music  Probability:  0.0%
# Burning_short_8.wav  Label:  Ambient music  Probability:  0.0%
# Burning_short_8.wav  Label:  Trance music  Probability:  0.0%
# Burning_short_8.wav  Label:  Music of Latin America  Probability:  0.0%
# Burning_short_8.wav  Label:  Salsa music  Probability:  0.0%
# Burning_short_8.wav  Label:  Flamenco  Probability:  0.0%
# Burning_short_8.wav  Label:  Blues  Probability:  0.0%
# Burning_short_8.wav  Label:  Music for children  Probability:  0.0%
# Burning_short_8.wav  Label:  New-age music  Probability:  0.0%
# Burning_short_8.wav  Label:  Vocal music  Probability:  0.0%
# Burning_short_8.wav  Label:  A capella  Probability:  0.0%
# Burning_short_8.wav  Label:  Music of Africa  Probability:  0.0%
# Burning_short_8.wav  Label:  Afrobeat  Probability:  0.0%
# Burning_short_8.wav  Label:  Christian music  Probability:  0.0%
# Burning_short_8.wav  Label:  Gospel music  Probability:  0.0%
# Burning_short_8.wav  Label:  Music of Asia  Probability:  0.0%
# Burning_short_8.wav  Label:  Carnatic music  Probability:  0.0%
# Burning_short_8.wav  Label:  Music of Bollywood  Probability:  0.0%
# Burning_short_8.wav  Label:  Ska  Probability:  0.0%
# Burning_short_8.wav  Label:  Traditional music  Probability:  0.0%
# Burning_short_8.wav  Label:  Independent music  Probability:  0.0%
# Burning_short_8.wav  Label:  Song  Probability:  0.0%
# Burning_short_8.wav  Label:  Background music  Probability:  0.0%
# Burning_short_8.wav  Label:  Theme music  Probability:  0.0%
# Burning_short_8.wav  Label:  Jingle (music)  Probability:  0.0%
# Burning_short_8.wav  Label:  Soundtrack music  Probability:  0.1%
# Burning_short_8.wav  Label:  Lullaby  Probability:  0.0%
# Burning_short_8.wav  Label:  Video game music  Probability:  0.2%
# ...
# Burning_short_7.wav  Label:  Water  Probability:  0.1%
# Burning_short_7.wav  Label:  Rain  Probability:  0.0%
# Burning_short_7.wav  Label:  Raindrop  Probability:  0.0%
# Burning_short_7.wav  Label:  Rain on surface  Probability:  0.0%
# Burning_short_7.wav  Label:  Stream  Probability:  0.0%
# Burning_short_7.wav  Label:  Waterfall  Probability:  0.0%
# Burning_short_7.wav  Label:  Ocean  Probability:  0.0%
# Burning_short_7.wav  Label:  Waves, surf  Probability:  0.0%
# Burning_short_7.wav  Label:  Steam  Probability:  0.1%
# Burning_short_7.wav  Label:  Gurgling  Probability:  0.0%
# Burning_short_7.wav  Label:  Fire  Probability:  0.0%
# Burning_short_7.wav  Label:  Crackle  Probability:  0.0%
# Burning_short_7.wav  Label:  Vehicle  Probability:  1.6%
# Burning_short_7.wav  Label:  Boat, Water vehicle  Probability:  0.0%
# Burning_short_7.wav  Label:  Sailboat, sailing ship  Probability:  0.0%
# Burning_short_7.wav  Label:  Rowboat, canoe, kayak  Probability:  0.0%
# Burning_short_7.wav  Label:  Motorboat, speedboat  Probability:  0.0%
# Burning_short_7.wav  Label:  Ship  Probability:  0.0%
# Burning_short_7.wav  Label:  Motor vehicle (road)  Probability:  1.6%
# Burning_short_7.wav  Label:  Car  Probability:  1.3%
# Burning_short_7.wav  Label:  Vehicle horn, car horn, honking  Probability:  0.0%
# Burning_short_7.wav  Label:  Toot  Probability:  0.0%
# Burning_short_7.wav  Label:  Car alarm  Probability:  0.0%
# Burning_short_7.wav  Label:  Power windows, electric windows  Probability:  0.0%
# Burning_short_7.wav  Label:  Skidding  Probability:  0.0%
# Burning_short_7.wav  Label:  Tire squeal  Probability:  0.1%
# Burning_short_7.wav  Label:  Car passing by  Probability:  0.2%
# Burning_short_7.wav  Label:  Race car, auto racing  Probability:  0.1%
# Burning_short_7.wav  Label:  Truck  Probability:  0.3%
# Burning_short_7.wav  Label:  Air brake  Probability:  0.1%
# Burning_short_7.wav  Label:  Air horn, truck horn  Probability:  0.0%
# Burning_short_7.wav  Label:  Reversing beeps  Probability:  0.0%
# Burning_short_7.wav  Label:  Ice cream truck, ice cream van  Probability:  0.0%
# Burning_short_7.wav  Label:  Bus  Probability:  0.1%
# Burning_short_7.wav  Label:  Emergency vehicle  Probability:  0.0%
# Burning_short_7.wav  Label:  Police car (siren)  Probability:  0.1%
# Burning_short_7.wav  Label:  Ambulance (siren)  Probability:  0.0%
# Burning_short_7.wav  Label:  Fire engine, fire truck (siren)  Probability:  0.0%
# Burning_short_7.wav  Label:  Motorcycle  Probability:  0.2%
# Burning_short_7.wav  Label:  Traffic noise, roadway noise  Probability:  0.0%
# Burning_short_7.wav  Label:  Rail transport  Probability:  0.2%
# Burning_short_7.wav  Label:  Train  Probability:  0.2%
# Burning_short_7.wav  Label:  Train whistle  Probability:  0.0%
# Burning_short_7.wav  Label:  Train horn  Probability:  0.0%
# Burning_short_7.wav  Label:  Railroad car, train wagon  Probability:  0.1%
# Burning_short_7.wav  Label:  Train wheels squealing  Probability:  0.0%
# Burning_short_7.wav  Label:  Subway, metro, underground  Probability:  0.0%
# Burning_short_7.wav  Label:  Aircraft  Probability:  0.0%
# Burning_short_7.wav  Label:  Aircraft engine  Probability:  0.0%
# Burning_short_7.wav  Label:  Jet engine  Probability:  0.0%
# Burning_short_7.wav  Label:  Propeller, airscrew  Probability:  0.0%
# Burning_short_7.wav  Label:  Helicopter  Probability:  0.0%
# Burning_short_7.wav  Label:  Fixed-wing aircraft, airplane  Probability:  0.0%
# Burning_short_7.wav  Label:  Bicycle  Probability:  0.7%
# Burning_short_7.wav  Label:  Skateboard  Probability:  0.0%
# Burning_short_7.wav  Label:  Engine  Probability:  0.3%
# Burning_short_7.wav  Label:  Light engine (high frequency)  Probability:  0.1%
# Burning_short_7.wav  Label:  Dental drill, dentist's drill  Probability:  0.0%
# Burning_short_7.wav  Label:  Lawn mower  Probability:  0.0%
# Burning_short_7.wav  Label:  Chainsaw  Probability:  0.0%
# Burning_short_7.wav  Label:  Medium engine (mid frequency)  Probability:  0.1%
# Burning_short_7.wav  Label:  Heavy engine (low frequency)  Probability:  0.0%
# Burning_short_7.wav  Label:  Engine knocking  Probability:  0.0%
# Burning_short_7.wav  Label:  Engine starting  Probability:  0.1%
# Burning_short_7.wav  Label:  Idling  Probability:  0.0%
# Burning_short_7.wav  Label:  Accelerating, revving, vroom  Probability:  0.2%
# Burning_short_7.wav  Label:  Door  Probability:  0.5%
# Burning_short_7.wav  Label:  Doorbell  Probability:  0.0%
# Burning_short_7.wav  Label:  Ding-dong  Probability:  0.0%
# Burning_short_7.wav  Label:  Sliding door  Probability:  0.2%
# Burning_short_7.wav  Label:  Slam  Probability:  0.1%
# Burning_short_7.wav  Label:  Knock  Probability:  0.0%
# Burning_short_7.wav  Label:  Tap  Probability:  0.0%
# Burning_short_7.wav  Label:  Squeak  Probability:  0.0%
# Burning_short_7.wav  Label:  Cupboard open or close  Probability:  0.0%
# Burning_short_7.wav  Label:  Drawer open or close  Probability:  0.0%
# Burning_short_7.wav  Label:  Dishes, pots, and pans  Probability:  0.1%
# Burning_short_7.wav  Label:  Cutlery, silverware  Probability:  0.0%
# Burning_short_7.wav  Label:  Chopping (food)  Probability:  0.0%
# Burning_short_7.wav  Label:  Frying (food)  Probability:  0.0%
# Burning_short_7.wav  Label:  Microwave oven  Probability:  0.0%
# Burning_short_7.wav  Label:  Blender  Probability:  0.1%
# Burning_short_7.wav  Label:  Water tap, faucet  Probability:  0.0%
# Burning_short_7.wav  Label:  Sink (filling or washing)  Probability:  0.0%
# Burning_short_7.wav  Label:  Bathtub (filling or washing)  Probability:  0.0%
# Burning_short_7.wav  Label:  Hair dryer  Probability:  0.0%
# Burning_short_7.wav  Label:  Toilet flush  Probability:  0.1%
# Burning_short_7.wav  Label:  Toothbrush  Probability:  0.0%
# Burning_short_7.wav  Label:  Electric toothbrush  Probability:  0.0%
# Burning_short_7.wav  Label:  Vacuum cleaner  Probability:  0.0%
# Burning_short_7.wav  Label:  Zipper (clothing)  Probability:  0.0%
# Burning_short_7.wav  Label:  Keys jangling  Probability:  0.0%
# Burning_short_7.wav  Label:  Coin (dropping)  Probability:  0.1%
# Burning_short_7.wav  Label:  Scissors  Probability:  0.0%
# Burning_short_7.wav  Label:  Electric shaver, electric razor  Probability:  0.0%
# Burning_short_7.wav  Label:  Shuffling cards  Probability:  0.0%
# Burning_short_7.wav  Label:  Typing  Probability:  0.0%
# Burning_short_7.wav  Label:  Typewriter  Probability:  0.0%
# Burning_short_7.wav  Label:  Computer keyboard  Probability:  0.0%
# Burning_short_7.wav  Label:  Writing  Probability:  0.0%
# Burning_short_7.wav  Label:  Alarm  Probability:  0.1%
# Burning_short_7.wav  Label:  Telephone  Probability:  0.1%
# Burning_short_7.wav  Label:  Telephone bell ringing  Probability:  0.0%
# Burning_short_7.wav  Label:  Ringtone  Probability:  0.0%
# Burning_short_7.wav  Label:  Telephone dialing, DTMF  Probability:  0.0%
# Burning_short_7.wav  Label:  Dial tone  Probability:  0.0%
# Burning_short_7.wav  Label:  Busy signal  Probability:  0.0%
# Burning_short_7.wav  Label:  Alarm clock  Probability:  0.0%
# Burning_short_7.wav  Label:  Siren  Probability:  0.0%
# Burning_short_7.wav  Label:  Civil defense siren  Probability:  0.0%
# Burning_short_7.wav  Label:  Buzzer  Probability:  0.0%
# Burning_short_7.wav  Label:  Smoke detector, smoke alarm  Probability:  0.0%
# Burning_short_7.wav  Label:  Fire alarm  Probability:  0.0%
# Burning_short_7.wav  Label:  Foghorn  Probability:  0.0%
# Burning_short_7.wav  Label:  Whistle  Probability:  0.0%
# Burning_short_7.wav  Label:  Steam whistle  Probability:  0.0%
# Burning_short_7.wav  Label:  Mechanisms  Probability:  2.0%
# Burning_short_7.wav  Label:  Ratchet, pawl  Probability:  0.8%
# Burning_short_7.wav  Label:  Clock  Probability:  0.1%
# Burning_short_7.wav  Label:  Tick  Probability:  0.0%
# Burning_short_7.wav  Label:  Tick-tock  Probability:  0.0%
# Burning_short_7.wav  Label:  Gears  Probability:  0.2%
# Burning_short_7.wav  Label:  Pulleys  Probability:  0.0%
# Burning_short_7.wav  Label:  Sewing machine  Probability:  0.1%
# Burning_short_7.wav  Label:  Mechanical fan  Probability:  0.0%
# Burning_short_7.wav  Label:  Air conditioning  Probability:  0.0%
# Burning_short_7.wav  Label:  Cash register  Probability:  0.0%
# Burning_short_7.wav  Label:  Printer  Probability:  0.2%
# Burning_short_7.wav  Label:  Camera  Probability:  0.0%
# Burning_short_7.wav  Label:  Single-lens reflex camera  Probability:  0.0%
# Burning_short_7.wav  Label:  Tools  Probability:  2.2%
# Burning_short_7.wav  Label:  Hammer  Probability:  0.0%
# Burning_short_7.wav  Label:  Jackhammer  Probability:  0.0%
# Burning_short_7.wav  Label:  Sawing  Probability:  0.0%
# Burning_short_7.wav  Label:  Filing (rasp)  Probability:  0.0%
# Burning_short_7.wav  Label:  Sanding  Probability:  0.0%
# Burning_short_7.wav  Label:  Power tool  Probability:  0.7%
# Burning_short_7.wav  Label:  Drill  Probability:  0.4%
# Burning_short_7.wav  Label:  Explosion  Probability:  0.4%
# Burning_short_7.wav  Label:  Gunshot, gunfire  Probability:  0.1%
# Burning_short_7.wav  Label:  Machine gun  Probability:  0.0%
# Burning_short_7.wav  Label:  Fusillade  Probability:  0.0%
# Burning_short_7.wav  Label:  Artillery fire  Probability:  0.0%
# Burning_short_7.wav  Label:  Cap gun  Probability:  0.0%
# Burning_short_7.wav  Label:  Fireworks  Probability:  0.0%
# Burning_short_7.wav  Label:  Firecracker  Probability:  0.0%
# Burning_short_7.wav  Label:  Burst, pop  Probability:  0.3%
# Burning_short_7.wav  Label:  Eruption  Probability:  0.0%
# Burning_short_7.wav  Label:  Boom  Probability:  0.5%
# Burning_short_7.wav  Label:  Wood  Probability:  0.4%
# Burning_short_7.wav  Label:  Chop  Probability:  0.0%
# Burning_short_7.wav  Label:  Splinter  Probability:  0.0%
# Burning_short_7.wav  Label:  Crack  Probability:  0.0%
# Burning_short_7.wav  Label:  Glass  Probability:  2.5%
# Burning_short_7.wav  Label:  Chink, clink  Probability:  0.2%
# Burning_short_7.wav  Label:  Shatter  Probability:  0.2%
# Burning_short_7.wav  Label:  Liquid  Probability:  0.1%
# Burning_short_7.wav  Label:  Splash, splatter  Probability:  0.0%
# Burning_short_7.wav  Label:  Slosh  Probability:  0.0%
# Burning_short_7.wav  Label:  Squish  Probability:  0.0%
# Burning_short_7.wav  Label:  Drip  Probability:  0.0%
# Burning_short_7.wav  Label:  Pour  Probability:  0.0%
# Burning_short_7.wav  Label:  Trickle, dribble  Probability:  0.0%
# Burning_short_7.wav  Label:  Gush  Probability:  0.0%
# Burning_short_7.wav  Label:  Fill (with liquid)  Probability:  0.0%
# Burning_short_7.wav  Label:  Spray  Probability:  0.0%
# Burning_short_7.wav  Label:  Pump (liquid)  Probability:  0.0%
# Burning_short_7.wav  Label:  Stir  Probability:  0.0%
# Burning_short_7.wav  Label:  Boiling  Probability:  0.0%
# Burning_short_7.wav  Label:  Sonar  Probability:  0.0%
# Burning_short_7.wav  Label:  Arrow  Probability:  13.1%
# Burning_short_7.wav  Label:  Whoosh, swoosh, swish  Probability:  13.9%
# Burning_short_7.wav  Label:  Thump, thud  Probability:  2.3%
# Burning_short_7.wav  Label:  Thunk  Probability:  0.0%
# Burning_short_7.wav  Label:  Electronic tuner  Probability:  0.0%
# Burning_short_7.wav  Label:  Effects unit  Probability:  0.0%
# Burning_short_7.wav  Label:  Chorus effect  Probability:  0.0%
# Burning_short_7.wav  Label:  Basketball bounce  Probability:  0.2%
# Burning_short_7.wav  Label:  Bang  Probability:  0.0%
# Burning_short_7.wav  Label:  Slap, smack  Probability:  0.0%
# Burning_short_7.wav  Label:  Whack, thwack  Probability:  0.3%
# Burning_short_7.wav  Label:  Smash, crash  Probability:  1.0%
# Burning_short_7.wav  Label:  Breaking  Probability:  0.1%
# Burning_short_7.wav  Label:  Bouncing  Probability:  0.0%
# Burning_short_7.wav  Label:  Whip  Probability:  0.0%
# Burning_short_7.wav  Label:  Flap  Probability:  0.0%
# Burning_short_7.wav  Label:  Scratch  Probability:  0.0%
# Burning_short_7.wav  Label:  Scrape  Probability:  0.1%
# Burning_short_7.wav  Label:  Rub  Probability:  0.0%
# Burning_short_7.wav  Label:  Roll  Probability:  0.0%
# Burning_short_7.wav  Label:  Crushing  Probability:  0.0%
# Burning_short_7.wav  Label:  Crumpling, crinkling  Probability:  0.0%
# Burning_short_7.wav  Label:  Tearing  Probability:  0.0%
# Burning_short_7.wav  Label:  Beep, bleep  Probability:  0.0%
# Burning_short_7.wav  Label:  Ping  Probability:  0.0%
# Burning_short_7.wav  Label:  Ding  Probability:  0.0%
# Burning_short_7.wav  Label:  Clang  Probability:  0.0%
# Burning_short_7.wav  Label:  Squeal  Probability:  1.0%
# Burning_short_7.wav  Label:  Creak  Probability:  0.0%
# Burning_short_7.wav  Label:  Rustle  Probability:  0.3%
# Burning_short_7.wav  Label:  Whir  Probability:  0.0%
# Burning_short_7.wav  Label:  Clatter  Probability:  0.8%
# Burning_short_7.wav  Label:  Sizzle  Probability:  0.0%
# Burning_short_7.wav  Label:  Clicking  Probability:  0.0%
# Burning_short_7.wav  Label:  Clickety-clack  Probability:  0.0%
# Burning_short_7.wav  Label:  Rumble  Probability:  0.8%
# Burning_short_7.wav  Label:  Plop  Probability:  0.0%
# Burning_short_7.wav  Label:  Jingle, tinkle  Probability:  0.0%
# Burning_short_7.wav  Label:  Hum  Probability:  0.0%
# Burning_short_7.wav  Label:  Zing  Probability:  0.0%
# Burning_short_7.wav  Label:  Boing  Probability:  0.0%
# Burning_short_7.wav  Label:  Crunch  Probability:  0.0%
# Burning_short_7.wav  Label:  Silence  Probability:  0.0%
# Burning_short_7.wav  Label:  Sine wave  Probability:  0.0%
# Burning_short_7.wav  Label:  Harmonic  Probability:  0.0%
# Burning_short_7.wav  Label:  Chirp tone  Probability:  0.0%
# Burning_short_7.wav  Label:  Sound effect  Probability:  8.9%
# Burning_short_7.wav  Label:  Pulse  Probability:  0.0%
# Burning_short_7.wav  Label:  Inside, small room  Probability:  1.9%
# Burning_short_7.wav  Label:  Inside, large room or hall  Probability:  3.6%
# Burning_short_7.wav  Label:  Inside, public space  Probability:  0.2%
# Burning_short_7.wav  Label:  Outside, urban or manmade  Probability:  1.4%
# Burning_short_7.wav  Label:  Outside, rural or natural  Probability:  1.2%
# Burning_short_7.wav  Label:  Reverberation  Probability:  0.1%
# Burning_short_7.wav  Label:  Echo  Probability:  0.2%
# Burning_short_7.wav  Label:  Noise  Probability:  0.1%
# Burning_short_7.wav  Label:  Environmental noise  Probability:  0.0%
# Burning_short_7.wav  Label:  Static  Probability:  0.0%
# Burning_short_7.wav  Label:  Mains hum  Probability:  0.0%
# Burning_short_7.wav  Label:  Distortion  Probability:  0.0%
# Burning_short_7.wav  Label:  Sidetone  Probability:  0.0%
# Burning_short_7.wav  Label:  Cacophony  Probability:  0.1%
# Burning_short_7.wav  Label:  White noise  Probability:  0.0%
# Burning_short_7.wav  Label:  Pink noise  Probability:  0.0%
# Burning_short_7.wav  Label:  Throbbing  Probability:  0.0%
# Burning_short_7.wav  Label:  Vibration  Probability:  0.1%
# Burning_short_7.wav  Label:  Television  Probability:  0.4%
# Burning_short_7.wav  Label:  Radio  Probability:  0.0%
# Burning_short_7.wav  Label:  Field recording  Probability:  0.0%
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`
# 2023-08-28 13:54:37.344917: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# 2023-08-28 13:54:37.368155: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`
# [   INFO   ] TensorflowPredict: Successfully loaded graph file: `../../models/audioset-yamnet-1.pb`

# %% [markdown]
# ## Export Stats

# %% [markdown]
# Finaly, to export the results, we iterate over the list of audio files, extract their classification statistics, and save the statistics to a JSON files. If there is an analysis file dedicated to that audio file with the naming scheme defined bellow, we just add or update the values to the dictionary. At the end, we prompt the os to open the directory containing the files.

# %%
stats_folder = 'Audio Event'
stats_parent = 'YAMNet'
processor.export_data(stats, stats_folder, stats_parent)
